# %% [markdown]
# ## What Are Functions?

# %%
def a():
    print('a() was called.')
    b()
    print('a() is returning.')


def b():
    print('b() was called.')
    c()
    print('b() is returning.')


def c():
    print('c() was called.')
    print('c() is returning.')

# %%
a()
# Out:
# a() was called.
# b() was called.
# c() was called.
# c() is returning.
# b() is returning.
# a() is returning.
