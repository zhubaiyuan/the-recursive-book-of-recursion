# %% [markdown]
# ## What Is the Call Stack?

# %%
def a():
    spam = 'Ant'
    print('spam is ' + spam)
    b()
    print('spam is ' + spam)


def b():
    spam = 'Bobcat'
    print('spam is ' + spam)
    c()
    print('spam is ' + spam)


def c():
    spam = 'Coyote'
    print('spam is ' + spam)

# %%
a()
# Out:
# spam is Ant
# spam is Bobcat
# spam is Coyote
# spam is Bobcat
# spam is Ant
