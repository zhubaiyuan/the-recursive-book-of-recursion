# %% [markdown]
# ## What Are Recursive Functions and Stack Overflows?

# %%
def shortest():
    shortest()

# %%
shortest()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb#ch0000006?line=0'>1</a> shortest()
#
# /Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb Cell 2' in shortest()
#       <a href='vscode-notebook-cell:/Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb#ch0000005?line=0'>1</a> def shortest():
# ----> <a href='vscode-notebook-cell:/Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb#ch0000005?line=1'>2</a>     shortest()
#
# /Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb Cell 2' in shortest()
#       <a href='vscode-notebook-cell:/Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb#ch0000005?line=0'>1</a> def shortest():
# ----> <a href='vscode-notebook-cell:/Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb#ch0000005?line=1'>2</a>     shortest()
#
#     [... skipping similar frames: shortest at line 2 (2970 times)]
#
# /Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb Cell 2' in shortest()
#       <a href='vscode-notebook-cell:/Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb#ch0000005?line=0'>1</a> def shortest():
# ----> <a href='vscode-notebook-cell:/Users/baiyuan/projects/the-recursive-book-of-recursion/nb1_shortest_with_base_case.ipynb#ch0000005?line=1'>2</a>     shortest()
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ## Base Cases and Recursive Cases

# %%
def shortestWithBaseCase(makeRecursiveCall):
    print('shortestWithBaseCase(%s) called.' % makeRecursiveCall)
    # BASE CASE
    if not makeRecursiveCall:
        print('Returning from base case.')
        return
    # RECURSIVE CASE
    else:
        shortestWithBaseCase(False)
        print('Returning from recursive case.')
        return

# %%
print('Calling shortestWithBaseCase(False):')
shortestWithBaseCase(False)
# Out:
# Calling shortestWithBaseCase(False):
# shortestWithBaseCase(False) called.
# Returning from base case.

# %%
print('Calling shortestWithBaseCase(True):')
shortestWithBaseCase(True)
# Out:
# Calling shortestWithBaseCase(True):
# shortestWithBaseCase(True) called.
# shortestWithBaseCase(False) called.
# Returning from base case.
# Returning from recursive case.
