# %% [markdown]
# ## Finding All Permutations Without Repetition: A Wedding Seating Chart

# %%
def getPerms(chars, indent=0):
    print('.' * indent + 'Start of getPerms("' + chars + '")')
    # BASE CASE
    if len(chars) == 1:
        print('.' * indent + 'When chars = "' +
              chars + '" base case returns', chars)
        return [chars]
    # RECURSIVE CASE
    permutations = []
    head = chars[0]
    tail = chars[1:]
    tailPermutations = getPerms(tail, indent + 1)
    for tailPerm in tailPermutations:
        print('.' * indent + 'When chars =', chars,
              'putting head', head, 'in all places in', tailPerm)
        for i in range(len(tailPerm) + 1):
            newPerm = tailPerm[0:i] + head + tailPerm[i:]
            print('.' * indent + 'New permutation:', newPerm)
            permutations.append(newPerm)
    print('.' * indent + 'When chars =', chars, 'results are', permutations)
    return permutations

# %%
print('Permutations of "ABCD":')
print('Results:', ','.join(getPerms('ABCD')))
# Out:
# Permutations of "ABCD":
# Start of getPerms("ABCD")
# .Start of getPerms("BCD")
# ..Start of getPerms("CD")
# ...Start of getPerms("D")
# ...When chars = "D" base case returns D
# ..When chars = CD putting head C in all places in D
# ..New permutation: CD
# ..New permutation: DC
# ..When chars = CD results are ['CD', 'DC']
# .When chars = BCD putting head B in all places in CD
# .New permutation: BCD
# .New permutation: CBD
# .New permutation: CDB
# .When chars = BCD putting head B in all places in DC
# .New permutation: BDC
# .New permutation: DBC
# .New permutation: DCB
# .When chars = BCD results are ['BCD', 'CBD', 'CDB', 'BDC', 'DBC', 'DCB']
# When chars = ABCD putting head A in all places in BCD
# New permutation: ABCD
# New permutation: BACD
# New permutation: BCAD
# New permutation: BCDA
# When chars = ABCD putting head A in all places in CBD
# New permutation: ACBD
# New permutation: CABD
# New permutation: CBAD
# New permutation: CBDA
# When chars = ABCD putting head A in all places in CDB
# New permutation: ACDB
# New permutation: CADB
# New permutation: CDAB
# New permutation: CDBA
# When chars = ABCD putting head A in all places in BDC
# New permutation: ABDC
# New permutation: BADC
# New permutation: BDAC
# New permutation: BDCA
# When chars = ABCD putting head A in all places in DBC
# New permutation: ADBC
# New permutation: DABC
# New permutation: DBAC
# New permutation: DBCA
# When chars = ABCD putting head A in all places in DCB
# New permutation: ADCB
# New permutation: DACB
# New permutation: DCAB
# New permutation: DCBA
# When chars = ABCD results are ['ABCD', 'BACD', 'BCAD', 'BCDA', 'ACBD', 'CABD', 'CBAD', 'CBDA', 'ACDB', 'CADB', 'CDAB', 'CDBA', 'ABDC', 'BADC', 'BDAC', 'BDCA', 'ADBC', 'DABC', 'DBAC', 'DBCA', 'ADCB', 'DACB', 'DCAB', 'DCBA']
# Results: ABCD,BACD,BCAD,BCDA,ACBD,CABD,CBAD,CBDA,ACDB,CADB,CDAB,CDBA,ABDC,BADC,BDAC,BDCA,ADBC,DABC,DBAC,DBCA,ADCB,DACB,DCAB,DCBA

# %% [markdown]
# ## Getting Permutations with Nested Loops: A Less-Than-Ideal Approach

# %%
for a in ['A', 'B', 'C', 'D', 'E']:
    for b in ['A', 'B', 'C', 'D', 'E']:
        for c in ['A', 'B', 'C', 'D', 'E']:
            for d in ['A', 'B', 'C', 'D', 'E']:
                print(a, b, c, d)
# Out:
# A A A A
# A A A B
# A A A C
# A A A D
# A A A E
# A A B A
# A A B B
# A A B C
# A A B D
# A A B E
# A A C A
# A A C B
# A A C C
# A A C D
# A A C E
# A A D A
# A A D B
# A A D C
# A A D D
# A A D E
# A A E A
# A A E B
# A A E C
# A A E D
# A A E E
# A B A A
# A B A B
# A B A C
# A B A D
# A B A E
# A B B A
# A B B B
# A B B C
# A B B D
# A B B E
# A B C A
# A B C B
# A B C C
# A B C D
# A B C E
# A B D A
# A B D B
# A B D C
# A B D D
# A B D E
# A B E A
# A B E B
# A B E C
# A B E D
# A B E E
# A C A A
# A C A B
# A C A C
# A C A D
# A C A E
# A C B A
# A C B B
# A C B C
# A C B D
# A C B E
# A C C A
# A C C B
# A C C C
# A C C D
# A C C E
# A C D A
# A C D B
# A C D C
# A C D D
# A C D E
# A C E A
# A C E B
# A C E C
# A C E D
# A C E E
# A D A A
# A D A B
# A D A C
# A D A D
# A D A E
# A D B A
# A D B B
# A D B C
# A D B D
# A D B E
# A D C A
# A D C B
# A D C C
# A D C D
# A D C E
# A D D A
# A D D B
# A D D C
# A D D D
# A D D E
# A D E A
# A D E B
# A D E C
# A D E D
# A D E E
# A E A A
# A E A B
# A E A C
# A E A D
# A E A E
# A E B A
# A E B B
# A E B C
# A E B D
# A E B E
# A E C A
# A E C B
# A E C C
# A E C D
# A E C E
# A E D A
# A E D B
# A E D C
# A E D D
# A E D E
# A E E A
# A E E B
# A E E C
# A E E D
# A E E E
# B A A A
# B A A B
# B A A C
# B A A D
# B A A E
# B A B A
# B A B B
# B A B C
# B A B D
# B A B E
# B A C A
# B A C B
# B A C C
# B A C D
# B A C E
# B A D A
# B A D B
# B A D C
# B A D D
# B A D E
# B A E A
# B A E B
# B A E C
# B A E D
# B A E E
# B B A A
# B B A B
# B B A C
# B B A D
# B B A E
# B B B A
# B B B B
# B B B C
# B B B D
# B B B E
# B B C A
# B B C B
# B B C C
# B B C D
# B B C E
# B B D A
# B B D B
# B B D C
# B B D D
# B B D E
# B B E A
# B B E B
# B B E C
# B B E D
# B B E E
# B C A A
# B C A B
# B C A C
# B C A D
# B C A E
# B C B A
# B C B B
# B C B C
# B C B D
# B C B E
# B C C A
# B C C B
# B C C C
# B C C D
# B C C E
# B C D A
# B C D B
# B C D C
# B C D D
# B C D E
# B C E A
# B C E B
# B C E C
# B C E D
# B C E E
# B D A A
# B D A B
# B D A C
# B D A D
# B D A E
# B D B A
# B D B B
# B D B C
# B D B D
# B D B E
# B D C A
# B D C B
# B D C C
# B D C D
# B D C E
# B D D A
# B D D B
# B D D C
# B D D D
# B D D E
# B D E A
# B D E B
# B D E C
# B D E D
# B D E E
# B E A A
# B E A B
# B E A C
# B E A D
# B E A E
# B E B A
# B E B B
# B E B C
# B E B D
# B E B E
# B E C A
# B E C B
# B E C C
# B E C D
# B E C E
# B E D A
# B E D B
# B E D C
# B E D D
# B E D E
# B E E A
# B E E B
# B E E C
# B E E D
# B E E E
# C A A A
# C A A B
# C A A C
# C A A D
# C A A E
# C A B A
# C A B B
# C A B C
# C A B D
# C A B E
# C A C A
# C A C B
# C A C C
# C A C D
# C A C E
# C A D A
# C A D B
# C A D C
# C A D D
# C A D E
# C A E A
# C A E B
# C A E C
# C A E D
# C A E E
# C B A A
# C B A B
# C B A C
# C B A D
# C B A E
# C B B A
# C B B B
# C B B C
# C B B D
# C B B E
# C B C A
# C B C B
# C B C C
# C B C D
# C B C E
# C B D A
# C B D B
# C B D C
# C B D D
# C B D E
# C B E A
# C B E B
# C B E C
# C B E D
# C B E E
# C C A A
# C C A B
# C C A C
# C C A D
# C C A E
# C C B A
# C C B B
# C C B C
# C C B D
# C C B E
# C C C A
# C C C B
# C C C C
# C C C D
# C C C E
# C C D A
# C C D B
# C C D C
# C C D D
# C C D E
# C C E A
# C C E B
# C C E C
# C C E D
# C C E E
# C D A A
# C D A B
# C D A C
# C D A D
# C D A E
# C D B A
# C D B B
# C D B C
# C D B D
# C D B E
# C D C A
# C D C B
# C D C C
# C D C D
# C D C E
# C D D A
# C D D B
# C D D C
# C D D D
# C D D E
# C D E A
# C D E B
# C D E C
# C D E D
# C D E E
# C E A A
# C E A B
# C E A C
# C E A D
# C E A E
# C E B A
# C E B B
# C E B C
# C E B D
# C E B E
# C E C A
# C E C B
# C E C C
# C E C D
# C E C E
# C E D A
# C E D B
# C E D C
# C E D D
# C E D E
# C E E A
# C E E B
# C E E C
# C E E D
# C E E E
# D A A A
# D A A B
# D A A C
# D A A D
# D A A E
# D A B A
# D A B B
# D A B C
# D A B D
# D A B E
# D A C A
# D A C B
# D A C C
# D A C D
# D A C E
# D A D A
# D A D B
# D A D C
# D A D D
# D A D E
# D A E A
# D A E B
# D A E C
# D A E D
# D A E E
# D B A A
# D B A B
# D B A C
# D B A D
# D B A E
# D B B A
# D B B B
# D B B C
# D B B D
# D B B E
# D B C A
# D B C B
# D B C C
# D B C D
# D B C E
# D B D A
# D B D B
# D B D C
# D B D D
# D B D E
# D B E A
# D B E B
# D B E C
# D B E D
# D B E E
# D C A A
# D C A B
# D C A C
# D C A D
# D C A E
# D C B A
# D C B B
# D C B C
# D C B D
# D C B E
# D C C A
# D C C B
# D C C C
# D C C D
# D C C E
# D C D A
# D C D B
# D C D C
# D C D D
# D C D E
# D C E A
# D C E B
# D C E C
# D C E D
# D C E E
# D D A A
# D D A B
# D D A C
# D D A D
# D D A E
# D D B A
# D D B B
# D D B C
# D D B D
# D D B E
# D D C A
# D D C B
# D D C C
# D D C D
# D D C E
# D D D A
# D D D B
# D D D C
# D D D D
# D D D E
# D D E A
# D D E B
# D D E C
# D D E D
# D D E E
# D E A A
# D E A B
# D E A C
# D E A D
# D E A E
# D E B A
# D E B B
# D E B C
# D E B D
# D E B E
# D E C A
# D E C B
# D E C C
# D E C D
# D E C E
# D E D A
# D E D B
# D E D C
# D E D D
# D E D E
# D E E A
# D E E B
# D E E C
# D E E D
# D E E E
# E A A A
# E A A B
# E A A C
# E A A D
# E A A E
# E A B A
# E A B B
# E A B C
# E A B D
# E A B E
# E A C A
# E A C B
# E A C C
# E A C D
# E A C E
# E A D A
# E A D B
# E A D C
# E A D D
# E A D E
# E A E A
# E A E B
# E A E C
# E A E D
# E A E E
# E B A A
# E B A B
# E B A C
# E B A D
# E B A E
# E B B A
# E B B B
# E B B C
# E B B D
# E B B E
# E B C A
# E B C B
# E B C C
# E B C D
# E B C E
# E B D A
# E B D B
# E B D C
# E B D D
# E B D E
# E B E A
# E B E B
# E B E C
# E B E D
# E B E E
# E C A A
# E C A B
# E C A C
# E C A D
# E C A E
# E C B A
# E C B B
# E C B C
# E C B D
# E C B E
# E C C A
# E C C B
# E C C C
# E C C D
# E C C E
# E C D A
# E C D B
# E C D C
# E C D D
# E C D E
# E C E A
# E C E B
# E C E C
# E C E D
# E C E E
# E D A A
# E D A B
# E D A C
# E D A D
# E D A E
# E D B A
# E D B B
# E D B C
# E D B D
# E D B E
# E D C A
# E D C B
# E D C C
# E D C D
# E D C E
# E D D A
# E D D B
# E D D C
# E D D D
# E D D E
# E D E A
# E D E B
# E D E C
# E D E D
# E D E E
# E E A A
# E E A B
# E E A C
# E E A D
# E E A E
# E E B A
# E E B B
# E E B C
# E E B D
# E E B E
# E E C A
# E E C B
# E E C C
# E E C D
# E E C E
# E E D A
# E E D B
# E E D C
# E E D D
# E E D E
# E E E A
# E E E B
# E E E C
# E E E D
# E E E E

# %% [markdown]
# ## Permutations with Repetition: A Password Cracker

# %%
def getPermsWithRep(chars, permLength=None, prefix=''):
    indent = '.' * len(prefix)
    print(indent + 'Start, args=("' + chars + '", ' +
          str(permLength) + ', "' + prefix + '")')
    if permLength is None:
        permLength = len(chars)
    # BASE CASE
    if (permLength == 0):
        print(indent + 'Base case reached, returning', [prefix])
        return [prefix]
    # RECURSIVE CASE
    # Create a new prefix by adding each character to the current prefix.
    results = []
    print(indent + 'Adding each char to prefix "' + prefix + '".')
    for char in chars:
        newPrefix = prefix + char
        # Decrease permLength by one because we added one character to the prefix.
        results.extend(getPermsWithRep(chars, permLength - 1, newPrefix))
    print(indent + 'Returning', results)
    return results

# %%
print('All permutations with repetition of JPB123:')
print(getPermsWithRep('JPB123', 4))
# Out:
# All permutations with repetition of JPB123:
# Start, args=("JPB123", 4, "")
# Adding each char to prefix "".
# .Start, args=("JPB123", 3, "J")
# .Adding each char to prefix "J".
# ..Start, args=("JPB123", 2, "JJ")
# ..Adding each char to prefix "JJ".
# ...Start, args=("JPB123", 1, "JJJ")
# ...Adding each char to prefix "JJJ".
# ....Start, args=("JPB123", 0, "JJJJ")
# ....Base case reached, returning ['JJJJ']
# ....Start, args=("JPB123", 0, "JJJP")
# ....Base case reached, returning ['JJJP']
# ....Start, args=("JPB123", 0, "JJJB")
# ....Base case reached, returning ['JJJB']
# ....Start, args=("JPB123", 0, "JJJ1")
# ....Base case reached, returning ['JJJ1']
# ....Start, args=("JPB123", 0, "JJJ2")
# ....Base case reached, returning ['JJJ2']
# ....Start, args=("JPB123", 0, "JJJ3")
# ....Base case reached, returning ['JJJ3']
# ...Returning ['JJJJ', 'JJJP', 'JJJB', 'JJJ1', 'JJJ2', 'JJJ3']
# ...Start, args=("JPB123", 1, "JJP")
# ...Adding each char to prefix "JJP".
# ....Start, args=("JPB123", 0, "JJPJ")
# ....Base case reached, returning ['JJPJ']
# ....Start, args=("JPB123", 0, "JJPP")
# ....Base case reached, returning ['JJPP']
# ....Start, args=("JPB123", 0, "JJPB")
# ....Base case reached, returning ['JJPB']
# ....Start, args=("JPB123", 0, "JJP1")
# ....Base case reached, returning ['JJP1']
# ....Start, args=("JPB123", 0, "JJP2")
# ....Base case reached, returning ['JJP2']
# ....Start, args=("JPB123", 0, "JJP3")
# ....Base case reached, returning ['JJP3']
# ...Returning ['JJPJ', 'JJPP', 'JJPB', 'JJP1', 'JJP2', 'JJP3']
# ...Start, args=("JPB123", 1, "JJB")
# ...Adding each char to prefix "JJB".
# ....Start, args=("JPB123", 0, "JJBJ")
# ....Base case reached, returning ['JJBJ']
# ....Start, args=("JPB123", 0, "JJBP")
# ....Base case reached, returning ['JJBP']
# ....Start, args=("JPB123", 0, "JJBB")
# ....Base case reached, returning ['JJBB']
# ....Start, args=("JPB123", 0, "JJB1")
# ....Base case reached, returning ['JJB1']
# ....Start, args=("JPB123", 0, "JJB2")
# ....Base case reached, returning ['JJB2']
# ....Start, args=("JPB123", 0, "JJB3")
# ....Base case reached, returning ['JJB3']
# ...Returning ['JJBJ', 'JJBP', 'JJBB', 'JJB1', 'JJB2', 'JJB3']
# ...Start, args=("JPB123", 1, "JJ1")
# ...Adding each char to prefix "JJ1".
# ....Start, args=("JPB123", 0, "JJ1J")
# ....Base case reached, returning ['JJ1J']
# ....Start, args=("JPB123", 0, "JJ1P")
# ....Base case reached, returning ['JJ1P']
# ....Start, args=("JPB123", 0, "JJ1B")
# ....Base case reached, returning ['JJ1B']
# ....Start, args=("JPB123", 0, "JJ11")
# ....Base case reached, returning ['JJ11']
# ....Start, args=("JPB123", 0, "JJ12")
# ....Base case reached, returning ['JJ12']
# ....Start, args=("JPB123", 0, "JJ13")
# ....Base case reached, returning ['JJ13']
# ...Returning ['JJ1J', 'JJ1P', 'JJ1B', 'JJ11', 'JJ12', 'JJ13']
# ...Start, args=("JPB123", 1, "JJ2")
# ...Adding each char to prefix "JJ2".
# ....Start, args=("JPB123", 0, "JJ2J")
# ....Base case reached, returning ['JJ2J']
# ....Start, args=("JPB123", 0, "JJ2P")
# ....Base case reached, returning ['JJ2P']
# ....Start, args=("JPB123", 0, "JJ2B")
# ....Base case reached, returning ['JJ2B']
# ....Start, args=("JPB123", 0, "JJ21")
# ....Base case reached, returning ['JJ21']
# ....Start, args=("JPB123", 0, "JJ22")
# ....Base case reached, returning ['JJ22']
# ....Start, args=("JPB123", 0, "JJ23")
# ....Base case reached, returning ['JJ23']
# ...Returning ['JJ2J', 'JJ2P', 'JJ2B', 'JJ21', 'JJ22', 'JJ23']
# ...Start, args=("JPB123", 1, "JJ3")
# ...Adding each char to prefix "JJ3".
# ....Start, args=("JPB123", 0, "JJ3J")
# ....Base case reached, returning ['JJ3J']
# ....Start, args=("JPB123", 0, "JJ3P")
# ....Base case reached, returning ['JJ3P']
# ....Start, args=("JPB123", 0, "JJ3B")
# ....Base case reached, returning ['JJ3B']
# ....Start, args=("JPB123", 0, "JJ31")
# ....Base case reached, returning ['JJ31']
# ....Start, args=("JPB123", 0, "JJ32")
# ....Base case reached, returning ['JJ32']
# ....Start, args=("JPB123", 0, "JJ33")
# ....Base case reached, returning ['JJ33']
# ...Returning ['JJ3J', 'JJ3P', 'JJ3B', 'JJ31', 'JJ32', 'JJ33']
# ..Returning ['JJJJ', 'JJJP', 'JJJB', 'JJJ1', 'JJJ2', 'JJJ3', 'JJPJ', 'JJPP', 'JJPB', 'JJP1', 'JJP2', 'JJP3', 'JJBJ', 'JJBP', 'JJBB', 'JJB1', 'JJB2', 'JJB3', 'JJ1J', 'JJ1P', 'JJ1B', 'JJ11', 'JJ12', 'JJ13', 'JJ2J', 'JJ2P', 'JJ2B', 'JJ21', 'JJ22', 'JJ23', 'JJ3J', 'JJ3P', 'JJ3B', 'JJ31', 'JJ32', 'JJ33']
# ..Start, args=("JPB123", 2, "JP")
# ..Adding each char to prefix "JP".
# ...Start, args=("JPB123", 1, "JPJ")
# ...Adding each char to prefix "JPJ".
# ....Start, args=("JPB123", 0, "JPJJ")
# ....Base case reached, returning ['JPJJ']
# ....Start, args=("JPB123", 0, "JPJP")
# ....Base case reached, returning ['JPJP']
# ....Start, args=("JPB123", 0, "JPJB")
# ....Base case reached, returning ['JPJB']
# ....Start, args=("JPB123", 0, "JPJ1")
# ....Base case reached, returning ['JPJ1']
# ....Start, args=("JPB123", 0, "JPJ2")
# ....Base case reached, returning ['JPJ2']
# ....Start, args=("JPB123", 0, "JPJ3")
# ....Base case reached, returning ['JPJ3']
# ...Returning ['JPJJ', 'JPJP', 'JPJB', 'JPJ1', 'JPJ2', 'JPJ3']
# ...Start, args=("JPB123", 1, "JPP")
# ...Adding each char to prefix "JPP".
# ....Start, args=("JPB123", 0, "JPPJ")
# ....Base case reached, returning ['JPPJ']
# ....Start, args=("JPB123", 0, "JPPP")
# ....Base case reached, returning ['JPPP']
# ....Start, args=("JPB123", 0, "JPPB")
# ....Base case reached, returning ['JPPB']
# ....Start, args=("JPB123", 0, "JPP1")
# ....Base case reached, returning ['JPP1']
# ....Start, args=("JPB123", 0, "JPP2")
# ....Base case reached, returning ['JPP2']
# ....Start, args=("JPB123", 0, "JPP3")
# ....Base case reached, returning ['JPP3']
# ...Returning ['JPPJ', 'JPPP', 'JPPB', 'JPP1', 'JPP2', 'JPP3']
# ...Start, args=("JPB123", 1, "JPB")
# ...Adding each char to prefix "JPB".
# ....Start, args=("JPB123", 0, "JPBJ")
# ....Base case reached, returning ['JPBJ']
# ....Start, args=("JPB123", 0, "JPBP")
# ....Base case reached, returning ['JPBP']
# ....Start, args=("JPB123", 0, "JPBB")
# ....Base case reached, returning ['JPBB']
# ....Start, args=("JPB123", 0, "JPB1")
# ....Base case reached, returning ['JPB1']
# ....Start, args=("JPB123", 0, "JPB2")
# ....Base case reached, returning ['JPB2']
# ....Start, args=("JPB123", 0, "JPB3")
# ....Base case reached, returning ['JPB3']
# ...Returning ['JPBJ', 'JPBP', 'JPBB', 'JPB1', 'JPB2', 'JPB3']
# ...Start, args=("JPB123", 1, "JP1")
# ...Adding each char to prefix "JP1".
# ....Start, args=("JPB123", 0, "JP1J")
# ....Base case reached, returning ['JP1J']
# ....Start, args=("JPB123", 0, "JP1P")
# ....Base case reached, returning ['JP1P']
# ....Start, args=("JPB123", 0, "JP1B")
# ....Base case reached, returning ['JP1B']
# ....Start, args=("JPB123", 0, "JP11")
# ....Base case reached, returning ['JP11']
# ....Start, args=("JPB123", 0, "JP12")
# ....Base case reached, returning ['JP12']
# ....Start, args=("JPB123", 0, "JP13")
# ....Base case reached, returning ['JP13']
# ...Returning ['JP1J', 'JP1P', 'JP1B', 'JP11', 'JP12', 'JP13']
# ...Start, args=("JPB123", 1, "JP2")
# ...Adding each char to prefix "JP2".
# ....Start, args=("JPB123", 0, "JP2J")
# ....Base case reached, returning ['JP2J']
# ....Start, args=("JPB123", 0, "JP2P")
# ....Base case reached, returning ['JP2P']
# ....Start, args=("JPB123", 0, "JP2B")
# ....Base case reached, returning ['JP2B']
# ....Start, args=("JPB123", 0, "JP21")
# ....Base case reached, returning ['JP21']
# ....Start, args=("JPB123", 0, "JP22")
# ....Base case reached, returning ['JP22']
# ....Start, args=("JPB123", 0, "JP23")
# ....Base case reached, returning ['JP23']
# ...Returning ['JP2J', 'JP2P', 'JP2B', 'JP21', 'JP22', 'JP23']
# ...Start, args=("JPB123", 1, "JP3")
# ...Adding each char to prefix "JP3".
# ....Start, args=("JPB123", 0, "JP3J")
# ....Base case reached, returning ['JP3J']
# ....Start, args=("JPB123", 0, "JP3P")
# ....Base case reached, returning ['JP3P']
# ....Start, args=("JPB123", 0, "JP3B")
# ....Base case reached, returning ['JP3B']
# ....Start, args=("JPB123", 0, "JP31")
# ....Base case reached, returning ['JP31']
# ....Start, args=("JPB123", 0, "JP32")
# ....Base case reached, returning ['JP32']
# ....Start, args=("JPB123", 0, "JP33")
# ....Base case reached, returning ['JP33']
# ...Returning ['JP3J', 'JP3P', 'JP3B', 'JP31', 'JP32', 'JP33']
# ..Returning ['JPJJ', 'JPJP', 'JPJB', 'JPJ1', 'JPJ2', 'JPJ3', 'JPPJ', 'JPPP', 'JPPB', 'JPP1', 'JPP2', 'JPP3', 'JPBJ', 'JPBP', 'JPBB', 'JPB1', 'JPB2', 'JPB3', 'JP1J', 'JP1P', 'JP1B', 'JP11', 'JP12', 'JP13', 'JP2J', 'JP2P', 'JP2B', 'JP21', 'JP22', 'JP23', 'JP3J', 'JP3P', 'JP3B', 'JP31', 'JP32', 'JP33']
# ..Start, args=("JPB123", 2, "JB")
# ..Adding each char to prefix "JB".
# ...Start, args=("JPB123", 1, "JBJ")
# ...Adding each char to prefix "JBJ".
# ....Start, args=("JPB123", 0, "JBJJ")
# ....Base case reached, returning ['JBJJ']
# ....Start, args=("JPB123", 0, "JBJP")
# ....Base case reached, returning ['JBJP']
# ....Start, args=("JPB123", 0, "JBJB")
# ....Base case reached, returning ['JBJB']
# ....Start, args=("JPB123", 0, "JBJ1")
# ....Base case reached, returning ['JBJ1']
# ....Start, args=("JPB123", 0, "JBJ2")
# ....Base case reached, returning ['JBJ2']
# ....Start, args=("JPB123", 0, "JBJ3")
# ....Base case reached, returning ['JBJ3']
# ...Returning ['JBJJ', 'JBJP', 'JBJB', 'JBJ1', 'JBJ2', 'JBJ3']
# ...Start, args=("JPB123", 1, "JBP")
# ...Adding each char to prefix "JBP".
# ....Start, args=("JPB123", 0, "JBPJ")
# ....Base case reached, returning ['JBPJ']
# ....Start, args=("JPB123", 0, "JBPP")
# ....Base case reached, returning ['JBPP']
# ....Start, args=("JPB123", 0, "JBPB")
# ....Base case reached, returning ['JBPB']
# ....Start, args=("JPB123", 0, "JBP1")
# ....Base case reached, returning ['JBP1']
# ....Start, args=("JPB123", 0, "JBP2")
# ....Base case reached, returning ['JBP2']
# ....Start, args=("JPB123", 0, "JBP3")
# ....Base case reached, returning ['JBP3']
# ...Returning ['JBPJ', 'JBPP', 'JBPB', 'JBP1', 'JBP2', 'JBP3']
# ...Start, args=("JPB123", 1, "JBB")
# ...Adding each char to prefix "JBB".
# ....Start, args=("JPB123", 0, "JBBJ")
# ....Base case reached, returning ['JBBJ']
# ....Start, args=("JPB123", 0, "JBBP")
# ....Base case reached, returning ['JBBP']
# ....Start, args=("JPB123", 0, "JBBB")
# ....Base case reached, returning ['JBBB']
# ....Start, args=("JPB123", 0, "JBB1")
# ....Base case reached, returning ['JBB1']
# ....Start, args=("JPB123", 0, "JBB2")
# ....Base case reached, returning ['JBB2']
# ....Start, args=("JPB123", 0, "JBB3")
# ....Base case reached, returning ['JBB3']
# ...Returning ['JBBJ', 'JBBP', 'JBBB', 'JBB1', 'JBB2', 'JBB3']
# ...Start, args=("JPB123", 1, "JB1")
# ...Adding each char to prefix "JB1".
# ....Start, args=("JPB123", 0, "JB1J")
# ....Base case reached, returning ['JB1J']
# ....Start, args=("JPB123", 0, "JB1P")
# ....Base case reached, returning ['JB1P']
# ....Start, args=("JPB123", 0, "JB1B")
# ....Base case reached, returning ['JB1B']
# ....Start, args=("JPB123", 0, "JB11")
# ....Base case reached, returning ['JB11']
# ....Start, args=("JPB123", 0, "JB12")
# ....Base case reached, returning ['JB12']
# ....Start, args=("JPB123", 0, "JB13")
# ....Base case reached, returning ['JB13']
# ...Returning ['JB1J', 'JB1P', 'JB1B', 'JB11', 'JB12', 'JB13']
# ...Start, args=("JPB123", 1, "JB2")
# ...Adding each char to prefix "JB2".
# ....Start, args=("JPB123", 0, "JB2J")
# ....Base case reached, returning ['JB2J']
# ....Start, args=("JPB123", 0, "JB2P")
# ....Base case reached, returning ['JB2P']
# ....Start, args=("JPB123", 0, "JB2B")
# ....Base case reached, returning ['JB2B']
# ....Start, args=("JPB123", 0, "JB21")
# ....Base case reached, returning ['JB21']
# ....Start, args=("JPB123", 0, "JB22")
# ....Base case reached, returning ['JB22']
# ....Start, args=("JPB123", 0, "JB23")
# ....Base case reached, returning ['JB23']
# ...Returning ['JB2J', 'JB2P', 'JB2B', 'JB21', 'JB22', 'JB23']
# ...Start, args=("JPB123", 1, "JB3")
# ...Adding each char to prefix "JB3".
# ....Start, args=("JPB123", 0, "JB3J")
# ....Base case reached, returning ['JB3J']
# ....Start, args=("JPB123", 0, "JB3P")
# ....Base case reached, returning ['JB3P']
# ....Start, args=("JPB123", 0, "JB3B")
# ....Base case reached, returning ['JB3B']
# ....Start, args=("JPB123", 0, "JB31")
# ....Base case reached, returning ['JB31']
# ....Start, args=("JPB123", 0, "JB32")
# ....Base case reached, returning ['JB32']
# ....Start, args=("JPB123", 0, "JB33")
# ....Base case reached, returning ['JB33']
# ...Returning ['JB3J', 'JB3P', 'JB3B', 'JB31', 'JB32', 'JB33']
# ..Returning ['JBJJ', 'JBJP', 'JBJB', 'JBJ1', 'JBJ2', 'JBJ3', 'JBPJ', 'JBPP', 'JBPB', 'JBP1', 'JBP2', 'JBP3', 'JBBJ', 'JBBP', 'JBBB', 'JBB1', 'JBB2', 'JBB3', 'JB1J', 'JB1P', 'JB1B', 'JB11', 'JB12', 'JB13', 'JB2J', 'JB2P', 'JB2B', 'JB21', 'JB22', 'JB23', 'JB3J', 'JB3P', 'JB3B', 'JB31', 'JB32', 'JB33']
# ..Start, args=("JPB123", 2, "J1")
# ..Adding each char to prefix "J1".
# ...Start, args=("JPB123", 1, "J1J")
# ...Adding each char to prefix "J1J".
# ....Start, args=("JPB123", 0, "J1JJ")
# ....Base case reached, returning ['J1JJ']
# ....Start, args=("JPB123", 0, "J1JP")
# ....Base case reached, returning ['J1JP']
# ....Start, args=("JPB123", 0, "J1JB")
# ....Base case reached, returning ['J1JB']
# ....Start, args=("JPB123", 0, "J1J1")
# ....Base case reached, returning ['J1J1']
# ....Start, args=("JPB123", 0, "J1J2")
# ....Base case reached, returning ['J1J2']
# ....Start, args=("JPB123", 0, "J1J3")
# ....Base case reached, returning ['J1J3']
# ...Returning ['J1JJ', 'J1JP', 'J1JB', 'J1J1', 'J1J2', 'J1J3']
# ...Start, args=("JPB123", 1, "J1P")
# ...Adding each char to prefix "J1P".
# ....Start, args=("JPB123", 0, "J1PJ")
# ....Base case reached, returning ['J1PJ']
# ....Start, args=("JPB123", 0, "J1PP")
# ....Base case reached, returning ['J1PP']
# ....Start, args=("JPB123", 0, "J1PB")
# ....Base case reached, returning ['J1PB']
# ....Start, args=("JPB123", 0, "J1P1")
# ....Base case reached, returning ['J1P1']
# ....Start, args=("JPB123", 0, "J1P2")
# ....Base case reached, returning ['J1P2']
# ....Start, args=("JPB123", 0, "J1P3")
# ....Base case reached, returning ['J1P3']
# ...Returning ['J1PJ', 'J1PP', 'J1PB', 'J1P1', 'J1P2', 'J1P3']
# ...Start, args=("JPB123", 1, "J1B")
# ...Adding each char to prefix "J1B".
# ....Start, args=("JPB123", 0, "J1BJ")
# ....Base case reached, returning ['J1BJ']
# ....Start, args=("JPB123", 0, "J1BP")
# ....Base case reached, returning ['J1BP']
# ....Start, args=("JPB123", 0, "J1BB")
# ....Base case reached, returning ['J1BB']
# ....Start, args=("JPB123", 0, "J1B1")
# ....Base case reached, returning ['J1B1']
# ....Start, args=("JPB123", 0, "J1B2")
# ....Base case reached, returning ['J1B2']
# ....Start, args=("JPB123", 0, "J1B3")
# ....Base case reached, returning ['J1B3']
# ...Returning ['J1BJ', 'J1BP', 'J1BB', 'J1B1', 'J1B2', 'J1B3']
# ...Start, args=("JPB123", 1, "J11")
# ...Adding each char to prefix "J11".
# ....Start, args=("JPB123", 0, "J11J")
# ....Base case reached, returning ['J11J']
# ....Start, args=("JPB123", 0, "J11P")
# ....Base case reached, returning ['J11P']
# ....Start, args=("JPB123", 0, "J11B")
# ....Base case reached, returning ['J11B']
# ....Start, args=("JPB123", 0, "J111")
# ....Base case reached, returning ['J111']
# ....Start, args=("JPB123", 0, "J112")
# ....Base case reached, returning ['J112']
# ....Start, args=("JPB123", 0, "J113")
# ....Base case reached, returning ['J113']
# ...Returning ['J11J', 'J11P', 'J11B', 'J111', 'J112', 'J113']
# ...Start, args=("JPB123", 1, "J12")
# ...Adding each char to prefix "J12".
# ....Start, args=("JPB123", 0, "J12J")
# ....Base case reached, returning ['J12J']
# ....Start, args=("JPB123", 0, "J12P")
# ....Base case reached, returning ['J12P']
# ....Start, args=("JPB123", 0, "J12B")
# ....Base case reached, returning ['J12B']
# ....Start, args=("JPB123", 0, "J121")
# ....Base case reached, returning ['J121']
# ....Start, args=("JPB123", 0, "J122")
# ....Base case reached, returning ['J122']
# ....Start, args=("JPB123", 0, "J123")
# ....Base case reached, returning ['J123']
# ...Returning ['J12J', 'J12P', 'J12B', 'J121', 'J122', 'J123']
# ...Start, args=("JPB123", 1, "J13")
# ...Adding each char to prefix "J13".
# ....Start, args=("JPB123", 0, "J13J")
# ....Base case reached, returning ['J13J']
# ....Start, args=("JPB123", 0, "J13P")
# ....Base case reached, returning ['J13P']
# ....Start, args=("JPB123", 0, "J13B")
# ....Base case reached, returning ['J13B']
# ....Start, args=("JPB123", 0, "J131")
# ....Base case reached, returning ['J131']
# ....Start, args=("JPB123", 0, "J132")
# ....Base case reached, returning ['J132']
# ....Start, args=("JPB123", 0, "J133")
# ....Base case reached, returning ['J133']
# ...Returning ['J13J', 'J13P', 'J13B', 'J131', 'J132', 'J133']
# ..Returning ['J1JJ', 'J1JP', 'J1JB', 'J1J1', 'J1J2', 'J1J3', 'J1PJ', 'J1PP', 'J1PB', 'J1P1', 'J1P2', 'J1P3', 'J1BJ', 'J1BP', 'J1BB', 'J1B1', 'J1B2', 'J1B3', 'J11J', 'J11P', 'J11B', 'J111', 'J112', 'J113', 'J12J', 'J12P', 'J12B', 'J121', 'J122', 'J123', 'J13J', 'J13P', 'J13B', 'J131', 'J132', 'J133']
# ..Start, args=("JPB123", 2, "J2")
# ..Adding each char to prefix "J2".
# ...Start, args=("JPB123", 1, "J2J")
# ...Adding each char to prefix "J2J".
# ....Start, args=("JPB123", 0, "J2JJ")
# ....Base case reached, returning ['J2JJ']
# ....Start, args=("JPB123", 0, "J2JP")
# ....Base case reached, returning ['J2JP']
# ....Start, args=("JPB123", 0, "J2JB")
# ....Base case reached, returning ['J2JB']
# ....Start, args=("JPB123", 0, "J2J1")
# ....Base case reached, returning ['J2J1']
# ....Start, args=("JPB123", 0, "J2J2")
# ....Base case reached, returning ['J2J2']
# ....Start, args=("JPB123", 0, "J2J3")
# ....Base case reached, returning ['J2J3']
# ...Returning ['J2JJ', 'J2JP', 'J2JB', 'J2J1', 'J2J2', 'J2J3']
# ...Start, args=("JPB123", 1, "J2P")
# ...Adding each char to prefix "J2P".
# ....Start, args=("JPB123", 0, "J2PJ")
# ....Base case reached, returning ['J2PJ']
# ....Start, args=("JPB123", 0, "J2PP")
# ....Base case reached, returning ['J2PP']
# ....Start, args=("JPB123", 0, "J2PB")
# ....Base case reached, returning ['J2PB']
# ....Start, args=("JPB123", 0, "J2P1")
# ....Base case reached, returning ['J2P1']
# ....Start, args=("JPB123", 0, "J2P2")
# ....Base case reached, returning ['J2P2']
# ....Start, args=("JPB123", 0, "J2P3")
# ....Base case reached, returning ['J2P3']
# ...Returning ['J2PJ', 'J2PP', 'J2PB', 'J2P1', 'J2P2', 'J2P3']
# ...Start, args=("JPB123", 1, "J2B")
# ...Adding each char to prefix "J2B".
# ....Start, args=("JPB123", 0, "J2BJ")
# ....Base case reached, returning ['J2BJ']
# ....Start, args=("JPB123", 0, "J2BP")
# ....Base case reached, returning ['J2BP']
# ....Start, args=("JPB123", 0, "J2BB")
# ....Base case reached, returning ['J2BB']
# ....Start, args=("JPB123", 0, "J2B1")
# ....Base case reached, returning ['J2B1']
# ....Start, args=("JPB123", 0, "J2B2")
# ....Base case reached, returning ['J2B2']
# ....Start, args=("JPB123", 0, "J2B3")
# ....Base case reached, returning ['J2B3']
# ...Returning ['J2BJ', 'J2BP', 'J2BB', 'J2B1', 'J2B2', 'J2B3']
# ...Start, args=("JPB123", 1, "J21")
# ...Adding each char to prefix "J21".
# ....Start, args=("JPB123", 0, "J21J")
# ....Base case reached, returning ['J21J']
# ....Start, args=("JPB123", 0, "J21P")
# ....Base case reached, returning ['J21P']
# ....Start, args=("JPB123", 0, "J21B")
# ....Base case reached, returning ['J21B']
# ....Start, args=("JPB123", 0, "J211")
# ....Base case reached, returning ['J211']
# ....Start, args=("JPB123", 0, "J212")
# ....Base case reached, returning ['J212']
# ....Start, args=("JPB123", 0, "J213")
# ....Base case reached, returning ['J213']
# ...Returning ['J21J', 'J21P', 'J21B', 'J211', 'J212', 'J213']
# ...Start, args=("JPB123", 1, "J22")
# ...Adding each char to prefix "J22".
# ....Start, args=("JPB123", 0, "J22J")
# ....Base case reached, returning ['J22J']
# ....Start, args=("JPB123", 0, "J22P")
# ....Base case reached, returning ['J22P']
# ....Start, args=("JPB123", 0, "J22B")
# ....Base case reached, returning ['J22B']
# ....Start, args=("JPB123", 0, "J221")
# ....Base case reached, returning ['J221']
# ....Start, args=("JPB123", 0, "J222")
# ....Base case reached, returning ['J222']
# ....Start, args=("JPB123", 0, "J223")
# ....Base case reached, returning ['J223']
# ...Returning ['J22J', 'J22P', 'J22B', 'J221', 'J222', 'J223']
# ...Start, args=("JPB123", 1, "J23")
# ...Adding each char to prefix "J23".
# ....Start, args=("JPB123", 0, "J23J")
# ....Base case reached, returning ['J23J']
# ....Start, args=("JPB123", 0, "J23P")
# ....Base case reached, returning ['J23P']
# ....Start, args=("JPB123", 0, "J23B")
# ....Base case reached, returning ['J23B']
# ....Start, args=("JPB123", 0, "J231")
# ....Base case reached, returning ['J231']
# ....Start, args=("JPB123", 0, "J232")
# ....Base case reached, returning ['J232']
# ....Start, args=("JPB123", 0, "J233")
# ....Base case reached, returning ['J233']
# ...Returning ['J23J', 'J23P', 'J23B', 'J231', 'J232', 'J233']
# ..Returning ['J2JJ', 'J2JP', 'J2JB', 'J2J1', 'J2J2', 'J2J3', 'J2PJ', 'J2PP', 'J2PB', 'J2P1', 'J2P2', 'J2P3', 'J2BJ', 'J2BP', 'J2BB', 'J2B1', 'J2B2', 'J2B3', 'J21J', 'J21P', 'J21B', 'J211', 'J212', 'J213', 'J22J', 'J22P', 'J22B', 'J221', 'J222', 'J223', 'J23J', 'J23P', 'J23B', 'J231', 'J232', 'J233']
# ..Start, args=("JPB123", 2, "J3")
# ..Adding each char to prefix "J3".
# ...Start, args=("JPB123", 1, "J3J")
# ...Adding each char to prefix "J3J".
# ....Start, args=("JPB123", 0, "J3JJ")
# ....Base case reached, returning ['J3JJ']
# ....Start, args=("JPB123", 0, "J3JP")
# ....Base case reached, returning ['J3JP']
# ....Start, args=("JPB123", 0, "J3JB")
# ....Base case reached, returning ['J3JB']
# ....Start, args=("JPB123", 0, "J3J1")
# ....Base case reached, returning ['J3J1']
# ....Start, args=("JPB123", 0, "J3J2")
# ....Base case reached, returning ['J3J2']
# ....Start, args=("JPB123", 0, "J3J3")
# ....Base case reached, returning ['J3J3']
# ...Returning ['J3JJ', 'J3JP', 'J3JB', 'J3J1', 'J3J2', 'J3J3']
# ...Start, args=("JPB123", 1, "J3P")
# ...Adding each char to prefix "J3P".
# ....Start, args=("JPB123", 0, "J3PJ")
# ....Base case reached, returning ['J3PJ']
# ....Start, args=("JPB123", 0, "J3PP")
# ....Base case reached, returning ['J3PP']
# ....Start, args=("JPB123", 0, "J3PB")
# ....Base case reached, returning ['J3PB']
# ....Start, args=("JPB123", 0, "J3P1")
# ....Base case reached, returning ['J3P1']
# ....Start, args=("JPB123", 0, "J3P2")
# ....Base case reached, returning ['J3P2']
# ....Start, args=("JPB123", 0, "J3P3")
# ....Base case reached, returning ['J3P3']
# ...Returning ['J3PJ', 'J3PP', 'J3PB', 'J3P1', 'J3P2', 'J3P3']
# ...Start, args=("JPB123", 1, "J3B")
# ...Adding each char to prefix "J3B".
# ....Start, args=("JPB123", 0, "J3BJ")
# ....Base case reached, returning ['J3BJ']
# ....Start, args=("JPB123", 0, "J3BP")
# ....Base case reached, returning ['J3BP']
# ....Start, args=("JPB123", 0, "J3BB")
# ....Base case reached, returning ['J3BB']
# ....Start, args=("JPB123", 0, "J3B1")
# ....Base case reached, returning ['J3B1']
# ....Start, args=("JPB123", 0, "J3B2")
# ....Base case reached, returning ['J3B2']
# ....Start, args=("JPB123", 0, "J3B3")
# ....Base case reached, returning ['J3B3']
# ...Returning ['J3BJ', 'J3BP', 'J3BB', 'J3B1', 'J3B2', 'J3B3']
# ...Start, args=("JPB123", 1, "J31")
# ...Adding each char to prefix "J31".
# ....Start, args=("JPB123", 0, "J31J")
# ....Base case reached, returning ['J31J']
# ....Start, args=("JPB123", 0, "J31P")
# ....Base case reached, returning ['J31P']
# ....Start, args=("JPB123", 0, "J31B")
# ....Base case reached, returning ['J31B']
# ....Start, args=("JPB123", 0, "J311")
# ....Base case reached, returning ['J311']
# ....Start, args=("JPB123", 0, "J312")
# ....Base case reached, returning ['J312']
# ....Start, args=("JPB123", 0, "J313")
# ....Base case reached, returning ['J313']
# ...Returning ['J31J', 'J31P', 'J31B', 'J311', 'J312', 'J313']
# ...Start, args=("JPB123", 1, "J32")
# ...Adding each char to prefix "J32".
# ....Start, args=("JPB123", 0, "J32J")
# ....Base case reached, returning ['J32J']
# ....Start, args=("JPB123", 0, "J32P")
# ....Base case reached, returning ['J32P']
# ....Start, args=("JPB123", 0, "J32B")
# ....Base case reached, returning ['J32B']
# ....Start, args=("JPB123", 0, "J321")
# ....Base case reached, returning ['J321']
# ....Start, args=("JPB123", 0, "J322")
# ....Base case reached, returning ['J322']
# ....Start, args=("JPB123", 0, "J323")
# ....Base case reached, returning ['J323']
# ...Returning ['J32J', 'J32P', 'J32B', 'J321', 'J322', 'J323']
# ...Start, args=("JPB123", 1, "J33")
# ...Adding each char to prefix "J33".
# ....Start, args=("JPB123", 0, "J33J")
# ....Base case reached, returning ['J33J']
# ....Start, args=("JPB123", 0, "J33P")
# ....Base case reached, returning ['J33P']
# ....Start, args=("JPB123", 0, "J33B")
# ....Base case reached, returning ['J33B']
# ....Start, args=("JPB123", 0, "J331")
# ....Base case reached, returning ['J331']
# ....Start, args=("JPB123", 0, "J332")
# ....Base case reached, returning ['J332']
# ....Start, args=("JPB123", 0, "J333")
# ....Base case reached, returning ['J333']
# ...Returning ['J33J', 'J33P', 'J33B', 'J331', 'J332', 'J333']
# ..Returning ['J3JJ', 'J3JP', 'J3JB', 'J3J1', 'J3J2', 'J3J3', 'J3PJ', 'J3PP', 'J3PB', 'J3P1', 'J3P2', 'J3P3', 'J3BJ', 'J3BP', 'J3BB', 'J3B1', 'J3B2', 'J3B3', 'J31J', 'J31P', 'J31B', 'J311', 'J312', 'J313', 'J32J', 'J32P', 'J32B', 'J321', 'J322', 'J323', 'J33J', 'J33P', 'J33B', 'J331', 'J332', 'J333']
# .Returning ['JJJJ', 'JJJP', 'JJJB', 'JJJ1', 'JJJ2', 'JJJ3', 'JJPJ', 'JJPP', 'JJPB', 'JJP1', 'JJP2', 'JJP3', 'JJBJ', 'JJBP', 'JJBB', 'JJB1', 'JJB2', 'JJB3', 'JJ1J', 'JJ1P', 'JJ1B', 'JJ11', 'JJ12', 'JJ13', 'JJ2J', 'JJ2P', 'JJ2B', 'JJ21', 'JJ22', 'JJ23', 'JJ3J', 'JJ3P', 'JJ3B', 'JJ31', 'JJ32', 'JJ33', 'JPJJ', 'JPJP', 'JPJB', 'JPJ1', 'JPJ2', 'JPJ3', 'JPPJ', 'JPPP', 'JPPB', 'JPP1', 'JPP2', 'JPP3', 'JPBJ', 'JPBP', 'JPBB', 'JPB1', 'JPB2', 'JPB3', 'JP1J', 'JP1P', 'JP1B', 'JP11', 'JP12', 'JP13', 'JP2J', 'JP2P', 'JP2B', 'JP21', 'JP22', 'JP23', 'JP3J', 'JP3P', 'JP3B', 'JP31', 'JP32', 'JP33', 'JBJJ', 'JBJP', 'JBJB', 'JBJ1', 'JBJ2', 'JBJ3', 'JBPJ', 'JBPP', 'JBPB', 'JBP1', 'JBP2', 'JBP3', 'JBBJ', 'JBBP', 'JBBB', 'JBB1', 'JBB2', 'JBB3', 'JB1J', 'JB1P', 'JB1B', 'JB11', 'JB12', 'JB13', 'JB2J', 'JB2P', 'JB2B', 'JB21', 'JB22', 'JB23', 'JB3J', 'JB3P', 'JB3B', 'JB31', 'JB32', 'JB33', 'J1JJ', 'J1JP', 'J1JB', 'J1J1', 'J1J2', 'J1J3', 'J1PJ', 'J1PP', 'J1PB', 'J1P1', 'J1P2', 'J1P3', 'J1BJ', 'J1BP', 'J1BB', 'J1B1', 'J1B2', 'J1B3', 'J11J', 'J11P', 'J11B', 'J111', 'J112', 'J113', 'J12J', 'J12P', 'J12B', 'J121', 'J122', 'J123', 'J13J', 'J13P', 'J13B', 'J131', 'J132', 'J133', 'J2JJ', 'J2JP', 'J2JB', 'J2J1', 'J2J2', 'J2J3', 'J2PJ', 'J2PP', 'J2PB', 'J2P1', 'J2P2', 'J2P3', 'J2BJ', 'J2BP', 'J2BB', 'J2B1', 'J2B2', 'J2B3', 'J21J', 'J21P', 'J21B', 'J211', 'J212', 'J213', 'J22J', 'J22P', 'J22B', 'J221', 'J222', 'J223', 'J23J', 'J23P', 'J23B', 'J231', 'J232', 'J233', 'J3JJ', 'J3JP', 'J3JB', 'J3J1', 'J3J2', 'J3J3', 'J3PJ', 'J3PP', 'J3PB', 'J3P1', 'J3P2', 'J3P3', 'J3BJ', 'J3BP', 'J3BB', 'J3B1', 'J3B2', 'J3B3', 'J31J', 'J31P', 'J31B', 'J311', 'J312', 'J313', 'J32J', 'J32P', 'J32B', 'J321', 'J322', 'J323', 'J33J', 'J33P', 'J33B', 'J331', 'J332', 'J333']
# .Start, args=("JPB123", 3, "P")
# .Adding each char to prefix "P".
# ..Start, args=("JPB123", 2, "PJ")
# ..Adding each char to prefix "PJ".
# ...Start, args=("JPB123", 1, "PJJ")
# ...Adding each char to prefix "PJJ".
# ....Start, args=("JPB123", 0, "PJJJ")
# ....Base case reached, returning ['PJJJ']
# ....Start, args=("JPB123", 0, "PJJP")
# ....Base case reached, returning ['PJJP']
# ....Start, args=("JPB123", 0, "PJJB")
# ....Base case reached, returning ['PJJB']
# ....Start, args=("JPB123", 0, "PJJ1")
# ....Base case reached, returning ['PJJ1']
# ....Start, args=("JPB123", 0, "PJJ2")
# ....Base case reached, returning ['PJJ2']
# ....Start, args=("JPB123", 0, "PJJ3")
# ....Base case reached, returning ['PJJ3']
# ...Returning ['PJJJ', 'PJJP', 'PJJB', 'PJJ1', 'PJJ2', 'PJJ3']
# ...Start, args=("JPB123", 1, "PJP")
# ...Adding each char to prefix "PJP".
# ....Start, args=("JPB123", 0, "PJPJ")
# ....Base case reached, returning ['PJPJ']
# ....Start, args=("JPB123", 0, "PJPP")
# ....Base case reached, returning ['PJPP']
# ....Start, args=("JPB123", 0, "PJPB")
# ....Base case reached, returning ['PJPB']
# ....Start, args=("JPB123", 0, "PJP1")
# ....Base case reached, returning ['PJP1']
# ....Start, args=("JPB123", 0, "PJP2")
# ....Base case reached, returning ['PJP2']
# ....Start, args=("JPB123", 0, "PJP3")
# ....Base case reached, returning ['PJP3']
# ...Returning ['PJPJ', 'PJPP', 'PJPB', 'PJP1', 'PJP2', 'PJP3']
# ...Start, args=("JPB123", 1, "PJB")
# ...Adding each char to prefix "PJB".
# ....Start, args=("JPB123", 0, "PJBJ")
# ....Base case reached, returning ['PJBJ']
# ....Start, args=("JPB123", 0, "PJBP")
# ....Base case reached, returning ['PJBP']
# ....Start, args=("JPB123", 0, "PJBB")
# ....Base case reached, returning ['PJBB']
# ....Start, args=("JPB123", 0, "PJB1")
# ....Base case reached, returning ['PJB1']
# ....Start, args=("JPB123", 0, "PJB2")
# ....Base case reached, returning ['PJB2']
# ....Start, args=("JPB123", 0, "PJB3")
# ....Base case reached, returning ['PJB3']
# ...Returning ['PJBJ', 'PJBP', 'PJBB', 'PJB1', 'PJB2', 'PJB3']
# ...Start, args=("JPB123", 1, "PJ1")
# ...Adding each char to prefix "PJ1".
# ....Start, args=("JPB123", 0, "PJ1J")
# ....Base case reached, returning ['PJ1J']
# ....Start, args=("JPB123", 0, "PJ1P")
# ....Base case reached, returning ['PJ1P']
# ....Start, args=("JPB123", 0, "PJ1B")
# ....Base case reached, returning ['PJ1B']
# ....Start, args=("JPB123", 0, "PJ11")
# ....Base case reached, returning ['PJ11']
# ....Start, args=("JPB123", 0, "PJ12")
# ....Base case reached, returning ['PJ12']
# ....Start, args=("JPB123", 0, "PJ13")
# ....Base case reached, returning ['PJ13']
# ...Returning ['PJ1J', 'PJ1P', 'PJ1B', 'PJ11', 'PJ12', 'PJ13']
# ...Start, args=("JPB123", 1, "PJ2")
# ...Adding each char to prefix "PJ2".
# ....Start, args=("JPB123", 0, "PJ2J")
# ....Base case reached, returning ['PJ2J']
# ....Start, args=("JPB123", 0, "PJ2P")
# ....Base case reached, returning ['PJ2P']
# ....Start, args=("JPB123", 0, "PJ2B")
# ....Base case reached, returning ['PJ2B']
# ....Start, args=("JPB123", 0, "PJ21")
# ....Base case reached, returning ['PJ21']
# ....Start, args=("JPB123", 0, "PJ22")
# ....Base case reached, returning ['PJ22']
# ....Start, args=("JPB123", 0, "PJ23")
# ....Base case reached, returning ['PJ23']
# ...Returning ['PJ2J', 'PJ2P', 'PJ2B', 'PJ21', 'PJ22', 'PJ23']
# ...Start, args=("JPB123", 1, "PJ3")
# ...Adding each char to prefix "PJ3".
# ....Start, args=("JPB123", 0, "PJ3J")
# ....Base case reached, returning ['PJ3J']
# ....Start, args=("JPB123", 0, "PJ3P")
# ....Base case reached, returning ['PJ3P']
# ....Start, args=("JPB123", 0, "PJ3B")
# ....Base case reached, returning ['PJ3B']
# ....Start, args=("JPB123", 0, "PJ31")
# ....Base case reached, returning ['PJ31']
# ....Start, args=("JPB123", 0, "PJ32")
# ....Base case reached, returning ['PJ32']
# ....Start, args=("JPB123", 0, "PJ33")
# ....Base case reached, returning ['PJ33']
# ...Returning ['PJ3J', 'PJ3P', 'PJ3B', 'PJ31', 'PJ32', 'PJ33']
# ..Returning ['PJJJ', 'PJJP', 'PJJB', 'PJJ1', 'PJJ2', 'PJJ3', 'PJPJ', 'PJPP', 'PJPB', 'PJP1', 'PJP2', 'PJP3', 'PJBJ', 'PJBP', 'PJBB', 'PJB1', 'PJB2', 'PJB3', 'PJ1J', 'PJ1P', 'PJ1B', 'PJ11', 'PJ12', 'PJ13', 'PJ2J', 'PJ2P', 'PJ2B', 'PJ21', 'PJ22', 'PJ23', 'PJ3J', 'PJ3P', 'PJ3B', 'PJ31', 'PJ32', 'PJ33']
# ..Start, args=("JPB123", 2, "PP")
# ..Adding each char to prefix "PP".
# ...Start, args=("JPB123", 1, "PPJ")
# ...Adding each char to prefix "PPJ".
# ....Start, args=("JPB123", 0, "PPJJ")
# ....Base case reached, returning ['PPJJ']
# ....Start, args=("JPB123", 0, "PPJP")
# ....Base case reached, returning ['PPJP']
# ....Start, args=("JPB123", 0, "PPJB")
# ....Base case reached, returning ['PPJB']
# ....Start, args=("JPB123", 0, "PPJ1")
# ....Base case reached, returning ['PPJ1']
# ....Start, args=("JPB123", 0, "PPJ2")
# ....Base case reached, returning ['PPJ2']
# ....Start, args=("JPB123", 0, "PPJ3")
# ....Base case reached, returning ['PPJ3']
# ...Returning ['PPJJ', 'PPJP', 'PPJB', 'PPJ1', 'PPJ2', 'PPJ3']
# ...Start, args=("JPB123", 1, "PPP")
# ...Adding each char to prefix "PPP".
# ....Start, args=("JPB123", 0, "PPPJ")
# ....Base case reached, returning ['PPPJ']
# ....Start, args=("JPB123", 0, "PPPP")
# ....Base case reached, returning ['PPPP']
# ....Start, args=("JPB123", 0, "PPPB")
# ....Base case reached, returning ['PPPB']
# ....Start, args=("JPB123", 0, "PPP1")
# ....Base case reached, returning ['PPP1']
# ....Start, args=("JPB123", 0, "PPP2")
# ....Base case reached, returning ['PPP2']
# ....Start, args=("JPB123", 0, "PPP3")
# ....Base case reached, returning ['PPP3']
# ...Returning ['PPPJ', 'PPPP', 'PPPB', 'PPP1', 'PPP2', 'PPP3']
# ...Start, args=("JPB123", 1, "PPB")
# ...Adding each char to prefix "PPB".
# ....Start, args=("JPB123", 0, "PPBJ")
# ....Base case reached, returning ['PPBJ']
# ....Start, args=("JPB123", 0, "PPBP")
# ....Base case reached, returning ['PPBP']
# ....Start, args=("JPB123", 0, "PPBB")
# ....Base case reached, returning ['PPBB']
# ....Start, args=("JPB123", 0, "PPB1")
# ....Base case reached, returning ['PPB1']
# ....Start, args=("JPB123", 0, "PPB2")
# ....Base case reached, returning ['PPB2']
# ....Start, args=("JPB123", 0, "PPB3")
# ....Base case reached, returning ['PPB3']
# ...Returning ['PPBJ', 'PPBP', 'PPBB', 'PPB1', 'PPB2', 'PPB3']
# ...Start, args=("JPB123", 1, "PP1")
# ...Adding each char to prefix "PP1".
# ....Start, args=("JPB123", 0, "PP1J")
# ....Base case reached, returning ['PP1J']
# ....Start, args=("JPB123", 0, "PP1P")
# ....Base case reached, returning ['PP1P']
# ....Start, args=("JPB123", 0, "PP1B")
# ....Base case reached, returning ['PP1B']
# ....Start, args=("JPB123", 0, "PP11")
# ....Base case reached, returning ['PP11']
# ....Start, args=("JPB123", 0, "PP12")
# ....Base case reached, returning ['PP12']
# ....Start, args=("JPB123", 0, "PP13")
# ....Base case reached, returning ['PP13']
# ...Returning ['PP1J', 'PP1P', 'PP1B', 'PP11', 'PP12', 'PP13']
# ...Start, args=("JPB123", 1, "PP2")
# ...Adding each char to prefix "PP2".
# ....Start, args=("JPB123", 0, "PP2J")
# ....Base case reached, returning ['PP2J']
# ....Start, args=("JPB123", 0, "PP2P")
# ....Base case reached, returning ['PP2P']
# ....Start, args=("JPB123", 0, "PP2B")
# ....Base case reached, returning ['PP2B']
# ....Start, args=("JPB123", 0, "PP21")
# ....Base case reached, returning ['PP21']
# ....Start, args=("JPB123", 0, "PP22")
# ....Base case reached, returning ['PP22']
# ....Start, args=("JPB123", 0, "PP23")
# ....Base case reached, returning ['PP23']
# ...Returning ['PP2J', 'PP2P', 'PP2B', 'PP21', 'PP22', 'PP23']
# ...Start, args=("JPB123", 1, "PP3")
# ...Adding each char to prefix "PP3".
# ....Start, args=("JPB123", 0, "PP3J")
# ....Base case reached, returning ['PP3J']
# ....Start, args=("JPB123", 0, "PP3P")
# ....Base case reached, returning ['PP3P']
# ....Start, args=("JPB123", 0, "PP3B")
# ....Base case reached, returning ['PP3B']
# ....Start, args=("JPB123", 0, "PP31")
# ....Base case reached, returning ['PP31']
# ....Start, args=("JPB123", 0, "PP32")
# ....Base case reached, returning ['PP32']
# ....Start, args=("JPB123", 0, "PP33")
# ....Base case reached, returning ['PP33']
# ...Returning ['PP3J', 'PP3P', 'PP3B', 'PP31', 'PP32', 'PP33']
# ..Returning ['PPJJ', 'PPJP', 'PPJB', 'PPJ1', 'PPJ2', 'PPJ3', 'PPPJ', 'PPPP', 'PPPB', 'PPP1', 'PPP2', 'PPP3', 'PPBJ', 'PPBP', 'PPBB', 'PPB1', 'PPB2', 'PPB3', 'PP1J', 'PP1P', 'PP1B', 'PP11', 'PP12', 'PP13', 'PP2J', 'PP2P', 'PP2B', 'PP21', 'PP22', 'PP23', 'PP3J', 'PP3P', 'PP3B', 'PP31', 'PP32', 'PP33']
# ..Start, args=("JPB123", 2, "PB")
# ..Adding each char to prefix "PB".
# ...Start, args=("JPB123", 1, "PBJ")
# ...Adding each char to prefix "PBJ".
# ....Start, args=("JPB123", 0, "PBJJ")
# ....Base case reached, returning ['PBJJ']
# ....Start, args=("JPB123", 0, "PBJP")
# ....Base case reached, returning ['PBJP']
# ....Start, args=("JPB123", 0, "PBJB")
# ....Base case reached, returning ['PBJB']
# ....Start, args=("JPB123", 0, "PBJ1")
# ....Base case reached, returning ['PBJ1']
# ....Start, args=("JPB123", 0, "PBJ2")
# ....Base case reached, returning ['PBJ2']
# ....Start, args=("JPB123", 0, "PBJ3")
# ....Base case reached, returning ['PBJ3']
# ...Returning ['PBJJ', 'PBJP', 'PBJB', 'PBJ1', 'PBJ2', 'PBJ3']
# ...Start, args=("JPB123", 1, "PBP")
# ...Adding each char to prefix "PBP".
# ....Start, args=("JPB123", 0, "PBPJ")
# ....Base case reached, returning ['PBPJ']
# ....Start, args=("JPB123", 0, "PBPP")
# ....Base case reached, returning ['PBPP']
# ....Start, args=("JPB123", 0, "PBPB")
# ....Base case reached, returning ['PBPB']
# ....Start, args=("JPB123", 0, "PBP1")
# ....Base case reached, returning ['PBP1']
# ....Start, args=("JPB123", 0, "PBP2")
# ....Base case reached, returning ['PBP2']
# ....Start, args=("JPB123", 0, "PBP3")
# ....Base case reached, returning ['PBP3']
# ...Returning ['PBPJ', 'PBPP', 'PBPB', 'PBP1', 'PBP2', 'PBP3']
# ...Start, args=("JPB123", 1, "PBB")
# ...Adding each char to prefix "PBB".
# ....Start, args=("JPB123", 0, "PBBJ")
# ....Base case reached, returning ['PBBJ']
# ....Start, args=("JPB123", 0, "PBBP")
# ....Base case reached, returning ['PBBP']
# ....Start, args=("JPB123", 0, "PBBB")
# ....Base case reached, returning ['PBBB']
# ....Start, args=("JPB123", 0, "PBB1")
# ....Base case reached, returning ['PBB1']
# ....Start, args=("JPB123", 0, "PBB2")
# ....Base case reached, returning ['PBB2']
# ....Start, args=("JPB123", 0, "PBB3")
# ....Base case reached, returning ['PBB3']
# ...Returning ['PBBJ', 'PBBP', 'PBBB', 'PBB1', 'PBB2', 'PBB3']
# ...Start, args=("JPB123", 1, "PB1")
# ...Adding each char to prefix "PB1".
# ....Start, args=("JPB123", 0, "PB1J")
# ....Base case reached, returning ['PB1J']
# ....Start, args=("JPB123", 0, "PB1P")
# ....Base case reached, returning ['PB1P']
# ....Start, args=("JPB123", 0, "PB1B")
# ....Base case reached, returning ['PB1B']
# ....Start, args=("JPB123", 0, "PB11")
# ....Base case reached, returning ['PB11']
# ....Start, args=("JPB123", 0, "PB12")
# ....Base case reached, returning ['PB12']
# ....Start, args=("JPB123", 0, "PB13")
# ....Base case reached, returning ['PB13']
# ...Returning ['PB1J', 'PB1P', 'PB1B', 'PB11', 'PB12', 'PB13']
# ...Start, args=("JPB123", 1, "PB2")
# ...Adding each char to prefix "PB2".
# ....Start, args=("JPB123", 0, "PB2J")
# ....Base case reached, returning ['PB2J']
# ....Start, args=("JPB123", 0, "PB2P")
# ....Base case reached, returning ['PB2P']
# ....Start, args=("JPB123", 0, "PB2B")
# ....Base case reached, returning ['PB2B']
# ....Start, args=("JPB123", 0, "PB21")
# ....Base case reached, returning ['PB21']
# ....Start, args=("JPB123", 0, "PB22")
# ....Base case reached, returning ['PB22']
# ....Start, args=("JPB123", 0, "PB23")
# ....Base case reached, returning ['PB23']
# ...Returning ['PB2J', 'PB2P', 'PB2B', 'PB21', 'PB22', 'PB23']
# ...Start, args=("JPB123", 1, "PB3")
# ...Adding each char to prefix "PB3".
# ....Start, args=("JPB123", 0, "PB3J")
# ....Base case reached, returning ['PB3J']
# ....Start, args=("JPB123", 0, "PB3P")
# ....Base case reached, returning ['PB3P']
# ....Start, args=("JPB123", 0, "PB3B")
# ....Base case reached, returning ['PB3B']
# ....Start, args=("JPB123", 0, "PB31")
# ....Base case reached, returning ['PB31']
# ....Start, args=("JPB123", 0, "PB32")
# ....Base case reached, returning ['PB32']
# ....Start, args=("JPB123", 0, "PB33")
# ....Base case reached, returning ['PB33']
# ...Returning ['PB3J', 'PB3P', 'PB3B', 'PB31', 'PB32', 'PB33']
# ..Returning ['PBJJ', 'PBJP', 'PBJB', 'PBJ1', 'PBJ2', 'PBJ3', 'PBPJ', 'PBPP', 'PBPB', 'PBP1', 'PBP2', 'PBP3', 'PBBJ', 'PBBP', 'PBBB', 'PBB1', 'PBB2', 'PBB3', 'PB1J', 'PB1P', 'PB1B', 'PB11', 'PB12', 'PB13', 'PB2J', 'PB2P', 'PB2B', 'PB21', 'PB22', 'PB23', 'PB3J', 'PB3P', 'PB3B', 'PB31', 'PB32', 'PB33']
# ..Start, args=("JPB123", 2, "P1")
# ..Adding each char to prefix "P1".
# ...Start, args=("JPB123", 1, "P1J")
# ...Adding each char to prefix "P1J".
# ....Start, args=("JPB123", 0, "P1JJ")
# ....Base case reached, returning ['P1JJ']
# ....Start, args=("JPB123", 0, "P1JP")
# ....Base case reached, returning ['P1JP']
# ....Start, args=("JPB123", 0, "P1JB")
# ....Base case reached, returning ['P1JB']
# ....Start, args=("JPB123", 0, "P1J1")
# ....Base case reached, returning ['P1J1']
# ....Start, args=("JPB123", 0, "P1J2")
# ....Base case reached, returning ['P1J2']
# ....Start, args=("JPB123", 0, "P1J3")
# ....Base case reached, returning ['P1J3']
# ...Returning ['P1JJ', 'P1JP', 'P1JB', 'P1J1', 'P1J2', 'P1J3']
# ...Start, args=("JPB123", 1, "P1P")
# ...Adding each char to prefix "P1P".
# ....Start, args=("JPB123", 0, "P1PJ")
# ....Base case reached, returning ['P1PJ']
# ....Start, args=("JPB123", 0, "P1PP")
# ....Base case reached, returning ['P1PP']
# ....Start, args=("JPB123", 0, "P1PB")
# ....Base case reached, returning ['P1PB']
# ....Start, args=("JPB123", 0, "P1P1")
# ....Base case reached, returning ['P1P1']
# ....Start, args=("JPB123", 0, "P1P2")
# ....Base case reached, returning ['P1P2']
# ....Start, args=("JPB123", 0, "P1P3")
# ....Base case reached, returning ['P1P3']
# ...Returning ['P1PJ', 'P1PP', 'P1PB', 'P1P1', 'P1P2', 'P1P3']
# ...Start, args=("JPB123", 1, "P1B")
# ...Adding each char to prefix "P1B".
# ....Start, args=("JPB123", 0, "P1BJ")
# ....Base case reached, returning ['P1BJ']
# ....Start, args=("JPB123", 0, "P1BP")
# ....Base case reached, returning ['P1BP']
# ....Start, args=("JPB123", 0, "P1BB")
# ....Base case reached, returning ['P1BB']
# ....Start, args=("JPB123", 0, "P1B1")
# ....Base case reached, returning ['P1B1']
# ....Start, args=("JPB123", 0, "P1B2")
# ....Base case reached, returning ['P1B2']
# ....Start, args=("JPB123", 0, "P1B3")
# ....Base case reached, returning ['P1B3']
# ...Returning ['P1BJ', 'P1BP', 'P1BB', 'P1B1', 'P1B2', 'P1B3']
# ...Start, args=("JPB123", 1, "P11")
# ...Adding each char to prefix "P11".
# ....Start, args=("JPB123", 0, "P11J")
# ....Base case reached, returning ['P11J']
# ....Start, args=("JPB123", 0, "P11P")
# ....Base case reached, returning ['P11P']
# ....Start, args=("JPB123", 0, "P11B")
# ....Base case reached, returning ['P11B']
# ....Start, args=("JPB123", 0, "P111")
# ....Base case reached, returning ['P111']
# ....Start, args=("JPB123", 0, "P112")
# ....Base case reached, returning ['P112']
# ....Start, args=("JPB123", 0, "P113")
# ....Base case reached, returning ['P113']
# ...Returning ['P11J', 'P11P', 'P11B', 'P111', 'P112', 'P113']
# ...Start, args=("JPB123", 1, "P12")
# ...Adding each char to prefix "P12".
# ....Start, args=("JPB123", 0, "P12J")
# ....Base case reached, returning ['P12J']
# ....Start, args=("JPB123", 0, "P12P")
# ....Base case reached, returning ['P12P']
# ....Start, args=("JPB123", 0, "P12B")
# ....Base case reached, returning ['P12B']
# ....Start, args=("JPB123", 0, "P121")
# ....Base case reached, returning ['P121']
# ....Start, args=("JPB123", 0, "P122")
# ....Base case reached, returning ['P122']
# ....Start, args=("JPB123", 0, "P123")
# ....Base case reached, returning ['P123']
# ...Returning ['P12J', 'P12P', 'P12B', 'P121', 'P122', 'P123']
# ...Start, args=("JPB123", 1, "P13")
# ...Adding each char to prefix "P13".
# ....Start, args=("JPB123", 0, "P13J")
# ....Base case reached, returning ['P13J']
# ....Start, args=("JPB123", 0, "P13P")
# ....Base case reached, returning ['P13P']
# ....Start, args=("JPB123", 0, "P13B")
# ....Base case reached, returning ['P13B']
# ....Start, args=("JPB123", 0, "P131")
# ....Base case reached, returning ['P131']
# ....Start, args=("JPB123", 0, "P132")
# ....Base case reached, returning ['P132']
# ....Start, args=("JPB123", 0, "P133")
# ....Base case reached, returning ['P133']
# ...Returning ['P13J', 'P13P', 'P13B', 'P131', 'P132', 'P133']
# ..Returning ['P1JJ', 'P1JP', 'P1JB', 'P1J1', 'P1J2', 'P1J3', 'P1PJ', 'P1PP', 'P1PB', 'P1P1', 'P1P2', 'P1P3', 'P1BJ', 'P1BP', 'P1BB', 'P1B1', 'P1B2', 'P1B3', 'P11J', 'P11P', 'P11B', 'P111', 'P112', 'P113', 'P12J', 'P12P', 'P12B', 'P121', 'P122', 'P123', 'P13J', 'P13P', 'P13B', 'P131', 'P132', 'P133']
# ..Start, args=("JPB123", 2, "P2")
# ..Adding each char to prefix "P2".
# ...Start, args=("JPB123", 1, "P2J")
# ...Adding each char to prefix "P2J".
# ....Start, args=("JPB123", 0, "P2JJ")
# ....Base case reached, returning ['P2JJ']
# ....Start, args=("JPB123", 0, "P2JP")
# ....Base case reached, returning ['P2JP']
# ....Start, args=("JPB123", 0, "P2JB")
# ....Base case reached, returning ['P2JB']
# ....Start, args=("JPB123", 0, "P2J1")
# ....Base case reached, returning ['P2J1']
# ....Start, args=("JPB123", 0, "P2J2")
# ....Base case reached, returning ['P2J2']
# ....Start, args=("JPB123", 0, "P2J3")
# ....Base case reached, returning ['P2J3']
# ...Returning ['P2JJ', 'P2JP', 'P2JB', 'P2J1', 'P2J2', 'P2J3']
# ...Start, args=("JPB123", 1, "P2P")
# ...Adding each char to prefix "P2P".
# ....Start, args=("JPB123", 0, "P2PJ")
# ....Base case reached, returning ['P2PJ']
# ....Start, args=("JPB123", 0, "P2PP")
# ....Base case reached, returning ['P2PP']
# ....Start, args=("JPB123", 0, "P2PB")
# ....Base case reached, returning ['P2PB']
# ....Start, args=("JPB123", 0, "P2P1")
# ....Base case reached, returning ['P2P1']
# ....Start, args=("JPB123", 0, "P2P2")
# ....Base case reached, returning ['P2P2']
# ....Start, args=("JPB123", 0, "P2P3")
# ....Base case reached, returning ['P2P3']
# ...Returning ['P2PJ', 'P2PP', 'P2PB', 'P2P1', 'P2P2', 'P2P3']
# ...Start, args=("JPB123", 1, "P2B")
# ...Adding each char to prefix "P2B".
# ....Start, args=("JPB123", 0, "P2BJ")
# ....Base case reached, returning ['P2BJ']
# ....Start, args=("JPB123", 0, "P2BP")
# ....Base case reached, returning ['P2BP']
# ....Start, args=("JPB123", 0, "P2BB")
# ....Base case reached, returning ['P2BB']
# ....Start, args=("JPB123", 0, "P2B1")
# ....Base case reached, returning ['P2B1']
# ....Start, args=("JPB123", 0, "P2B2")
# ....Base case reached, returning ['P2B2']
# ....Start, args=("JPB123", 0, "P2B3")
# ....Base case reached, returning ['P2B3']
# ...Returning ['P2BJ', 'P2BP', 'P2BB', 'P2B1', 'P2B2', 'P2B3']
# ...Start, args=("JPB123", 1, "P21")
# ...Adding each char to prefix "P21".
# ....Start, args=("JPB123", 0, "P21J")
# ....Base case reached, returning ['P21J']
# ....Start, args=("JPB123", 0, "P21P")
# ....Base case reached, returning ['P21P']
# ....Start, args=("JPB123", 0, "P21B")
# ....Base case reached, returning ['P21B']
# ....Start, args=("JPB123", 0, "P211")
# ....Base case reached, returning ['P211']
# ....Start, args=("JPB123", 0, "P212")
# ....Base case reached, returning ['P212']
# ....Start, args=("JPB123", 0, "P213")
# ....Base case reached, returning ['P213']
# ...Returning ['P21J', 'P21P', 'P21B', 'P211', 'P212', 'P213']
# ...Start, args=("JPB123", 1, "P22")
# ...Adding each char to prefix "P22".
# ....Start, args=("JPB123", 0, "P22J")
# ....Base case reached, returning ['P22J']
# ....Start, args=("JPB123", 0, "P22P")
# ....Base case reached, returning ['P22P']
# ....Start, args=("JPB123", 0, "P22B")
# ....Base case reached, returning ['P22B']
# ....Start, args=("JPB123", 0, "P221")
# ....Base case reached, returning ['P221']
# ....Start, args=("JPB123", 0, "P222")
# ....Base case reached, returning ['P222']
# ....Start, args=("JPB123", 0, "P223")
# ....Base case reached, returning ['P223']
# ...Returning ['P22J', 'P22P', 'P22B', 'P221', 'P222', 'P223']
# ...Start, args=("JPB123", 1, "P23")
# ...Adding each char to prefix "P23".
# ....Start, args=("JPB123", 0, "P23J")
# ....Base case reached, returning ['P23J']
# ....Start, args=("JPB123", 0, "P23P")
# ....Base case reached, returning ['P23P']
# ....Start, args=("JPB123", 0, "P23B")
# ....Base case reached, returning ['P23B']
# ....Start, args=("JPB123", 0, "P231")
# ....Base case reached, returning ['P231']
# ....Start, args=("JPB123", 0, "P232")
# ....Base case reached, returning ['P232']
# ....Start, args=("JPB123", 0, "P233")
# ....Base case reached, returning ['P233']
# ...Returning ['P23J', 'P23P', 'P23B', 'P231', 'P232', 'P233']
# ..Returning ['P2JJ', 'P2JP', 'P2JB', 'P2J1', 'P2J2', 'P2J3', 'P2PJ', 'P2PP', 'P2PB', 'P2P1', 'P2P2', 'P2P3', 'P2BJ', 'P2BP', 'P2BB', 'P2B1', 'P2B2', 'P2B3', 'P21J', 'P21P', 'P21B', 'P211', 'P212', 'P213', 'P22J', 'P22P', 'P22B', 'P221', 'P222', 'P223', 'P23J', 'P23P', 'P23B', 'P231', 'P232', 'P233']
# ..Start, args=("JPB123", 2, "P3")
# ..Adding each char to prefix "P3".
# ...Start, args=("JPB123", 1, "P3J")
# ...Adding each char to prefix "P3J".
# ....Start, args=("JPB123", 0, "P3JJ")
# ....Base case reached, returning ['P3JJ']
# ....Start, args=("JPB123", 0, "P3JP")
# ....Base case reached, returning ['P3JP']
# ....Start, args=("JPB123", 0, "P3JB")
# ....Base case reached, returning ['P3JB']
# ....Start, args=("JPB123", 0, "P3J1")
# ....Base case reached, returning ['P3J1']
# ....Start, args=("JPB123", 0, "P3J2")
# ....Base case reached, returning ['P3J2']
# ....Start, args=("JPB123", 0, "P3J3")
# ....Base case reached, returning ['P3J3']
# ...Returning ['P3JJ', 'P3JP', 'P3JB', 'P3J1', 'P3J2', 'P3J3']
# ...Start, args=("JPB123", 1, "P3P")
# ...Adding each char to prefix "P3P".
# ....Start, args=("JPB123", 0, "P3PJ")
# ....Base case reached, returning ['P3PJ']
# ....Start, args=("JPB123", 0, "P3PP")
# ....Base case reached, returning ['P3PP']
# ....Start, args=("JPB123", 0, "P3PB")
# ....Base case reached, returning ['P3PB']
# ....Start, args=("JPB123", 0, "P3P1")
# ....Base case reached, returning ['P3P1']
# ....Start, args=("JPB123", 0, "P3P2")
# ....Base case reached, returning ['P3P2']
# ....Start, args=("JPB123", 0, "P3P3")
# ....Base case reached, returning ['P3P3']
# ...Returning ['P3PJ', 'P3PP', 'P3PB', 'P3P1', 'P3P2', 'P3P3']
# ...Start, args=("JPB123", 1, "P3B")
# ...
# ...Start, args=("JPB123", 1, "321")
# ...Adding each char to prefix "321".
# ....Start, args=("JPB123", 0, "321J")
# ....Base case reached, returning ['321J']
# ....Start, args=("JPB123", 0, "321P")
# ....Base case reached, returning ['321P']
# ....Start, args=("JPB123", 0, "321B")
# ....Base case reached, returning ['321B']
# ....Start, args=("JPB123", 0, "3211")
# ....Base case reached, returning ['3211']
# ....Start, args=("JPB123", 0, "3212")
# ....Base case reached, returning ['3212']
# ....Start, args=("JPB123", 0, "3213")
# ....Base case reached, returning ['3213']
# ...Returning ['321J', '321P', '321B', '3211', '3212', '3213']
# ...Start, args=("JPB123", 1, "322")
# ...Adding each char to prefix "322".
# ....Start, args=("JPB123", 0, "322J")
# ....Base case reached, returning ['322J']
# ....Start, args=("JPB123", 0, "322P")
# ....Base case reached, returning ['322P']
# ....Start, args=("JPB123", 0, "322B")
# ....Base case reached, returning ['322B']
# ....Start, args=("JPB123", 0, "3221")
# ....Base case reached, returning ['3221']
# ....Start, args=("JPB123", 0, "3222")
# ....Base case reached, returning ['3222']
# ....Start, args=("JPB123", 0, "3223")
# ....Base case reached, returning ['3223']
# ...Returning ['322J', '322P', '322B', '3221', '3222', '3223']
# ...Start, args=("JPB123", 1, "323")
# ...Adding each char to prefix "323".
# ....Start, args=("JPB123", 0, "323J")
# ....Base case reached, returning ['323J']
# ....Start, args=("JPB123", 0, "323P")
# ....Base case reached, returning ['323P']
# ....Start, args=("JPB123", 0, "323B")
# ....Base case reached, returning ['323B']
# ....Start, args=("JPB123", 0, "3231")
# ....Base case reached, returning ['3231']
# ....Start, args=("JPB123", 0, "3232")
# ....Base case reached, returning ['3232']
# ....Start, args=("JPB123", 0, "3233")
# ....Base case reached, returning ['3233']
# ...Returning ['323J', '323P', '323B', '3231', '3232', '3233']
# ..Returning ['32JJ', '32JP', '32JB', '32J1', '32J2', '32J3', '32PJ', '32PP', '32PB', '32P1', '32P2', '32P3', '32BJ', '32BP', '32BB', '32B1', '32B2', '32B3', '321J', '321P', '321B', '3211', '3212', '3213', '322J', '322P', '322B', '3221', '3222', '3223', '323J', '323P', '323B', '3231', '3232', '3233']
# ..Start, args=("JPB123", 2, "33")
# ..Adding each char to prefix "33".
# ...Start, args=("JPB123", 1, "33J")
# ...Adding each char to prefix "33J".
# ....Start, args=("JPB123", 0, "33JJ")
# ....Base case reached, returning ['33JJ']
# ....Start, args=("JPB123", 0, "33JP")
# ....Base case reached, returning ['33JP']
# ....Start, args=("JPB123", 0, "33JB")
# ....Base case reached, returning ['33JB']
# ....Start, args=("JPB123", 0, "33J1")
# ....Base case reached, returning ['33J1']
# ....Start, args=("JPB123", 0, "33J2")
# ....Base case reached, returning ['33J2']
# ....Start, args=("JPB123", 0, "33J3")
# ....Base case reached, returning ['33J3']
# ...Returning ['33JJ', '33JP', '33JB', '33J1', '33J2', '33J3']
# ...Start, args=("JPB123", 1, "33P")
# ...Adding each char to prefix "33P".
# ....Start, args=("JPB123", 0, "33PJ")
# ....Base case reached, returning ['33PJ']
# ....Start, args=("JPB123", 0, "33PP")
# ....Base case reached, returning ['33PP']
# ....Start, args=("JPB123", 0, "33PB")
# ....Base case reached, returning ['33PB']
# ....Start, args=("JPB123", 0, "33P1")
# ....Base case reached, returning ['33P1']
# ....Start, args=("JPB123", 0, "33P2")
# ....Base case reached, returning ['33P2']
# ....Start, args=("JPB123", 0, "33P3")
# ....Base case reached, returning ['33P3']
# ...Returning ['33PJ', '33PP', '33PB', '33P1', '33P2', '33P3']
# ...Start, args=("JPB123", 1, "33B")
# ...Adding each char to prefix "33B".
# ....Start, args=("JPB123", 0, "33BJ")
# ....Base case reached, returning ['33BJ']
# ....Start, args=("JPB123", 0, "33BP")
# ....Base case reached, returning ['33BP']
# ....Start, args=("JPB123", 0, "33BB")
# ....Base case reached, returning ['33BB']
# ....Start, args=("JPB123", 0, "33B1")
# ....Base case reached, returning ['33B1']
# ....Start, args=("JPB123", 0, "33B2")
# ....Base case reached, returning ['33B2']
# ....Start, args=("JPB123", 0, "33B3")
# ....Base case reached, returning ['33B3']
# ...Returning ['33BJ', '33BP', '33BB', '33B1', '33B2', '33B3']
# ...Start, args=("JPB123", 1, "331")
# ...Adding each char to prefix "331".
# ....Start, args=("JPB123", 0, "331J")
# ....Base case reached, returning ['331J']
# ....Start, args=("JPB123", 0, "331P")
# ....Base case reached, returning ['331P']
# ....Start, args=("JPB123", 0, "331B")
# ....Base case reached, returning ['331B']
# ....Start, args=("JPB123", 0, "3311")
# ....Base case reached, returning ['3311']
# ....Start, args=("JPB123", 0, "3312")
# ....Base case reached, returning ['3312']
# ....Start, args=("JPB123", 0, "3313")
# ....Base case reached, returning ['3313']
# ...Returning ['331J', '331P', '331B', '3311', '3312', '3313']
# ...Start, args=("JPB123", 1, "332")
# ...Adding each char to prefix "332".
# ....Start, args=("JPB123", 0, "332J")
# ....Base case reached, returning ['332J']
# ....Start, args=("JPB123", 0, "332P")
# ....Base case reached, returning ['332P']
# ....Start, args=("JPB123", 0, "332B")
# ....Base case reached, returning ['332B']
# ....Start, args=("JPB123", 0, "3321")
# ....Base case reached, returning ['3321']
# ....Start, args=("JPB123", 0, "3322")
# ....Base case reached, returning ['3322']
# ....Start, args=("JPB123", 0, "3323")
# ....Base case reached, returning ['3323']
# ...Returning ['332J', '332P', '332B', '3321', '3322', '3323']
# ...Start, args=("JPB123", 1, "333")
# ...Adding each char to prefix "333".
# ....Start, args=("JPB123", 0, "333J")
# ....Base case reached, returning ['333J']
# ....Start, args=("JPB123", 0, "333P")
# ....Base case reached, returning ['333P']
# ....Start, args=("JPB123", 0, "333B")
# ....Base case reached, returning ['333B']
# ....Start, args=("JPB123", 0, "3331")
# ....Base case reached, returning ['3331']
# ....Start, args=("JPB123", 0, "3332")
# ....Base case reached, returning ['3332']
# ....Start, args=("JPB123", 0, "3333")
# ....Base case reached, returning ['3333']
# ...Returning ['333J', '333P', '333B', '3331', '3332', '3333']
# ..Returning ['33JJ', '33JP', '33JB', '33J1', '33J2', '33J3', '33PJ', '33PP', '33PB', '33P1', '33P2', '33P3', '33BJ', '33BP', '33BB', '33B1', '33B2', '33B3', '331J', '331P', '331B', '3311', '3312', '3313', '332J', '332P', '332B', '3321', '3322', '3323', '333J', '333P', '333B', '3331', '3332', '3333']
# .Returning ['3JJJ', '3JJP', '3JJB', '3JJ1', '3JJ2', '3JJ3', '3JPJ', '3JPP', '3JPB', '3JP1', '3JP2', '3JP3', '3JBJ', '3JBP', '3JBB', '3JB1', '3JB2', '3JB3', '3J1J', '3J1P', '3J1B', '3J11', '3J12', '3J13', '3J2J', '3J2P', '3J2B', '3J21', '3J22', '3J23', '3J3J', '3J3P', '3J3B', '3J31', '3J32', '3J33', '3PJJ', '3PJP', '3PJB', '3PJ1', '3PJ2', '3PJ3', '3PPJ', '3PPP', '3PPB', '3PP1', '3PP2', '3PP3', '3PBJ', '3PBP', '3PBB', '3PB1', '3PB2', '3PB3', '3P1J', '3P1P', '3P1B', '3P11', '3P12', '3P13', '3P2J', '3P2P', '3P2B', '3P21', '3P22', '3P23', '3P3J', '3P3P', '3P3B', '3P31', '3P32', '3P33', '3BJJ', '3BJP', '3BJB', '3BJ1', '3BJ2', '3BJ3', '3BPJ', '3BPP', '3BPB', '3BP1', '3BP2', '3BP3', '3BBJ', '3BBP', '3BBB', '3BB1', '3BB2', '3BB3', '3B1J', '3B1P', '3B1B', '3B11', '3B12', '3B13', '3B2J', '3B2P', '3B2B', '3B21', '3B22', '3B23', '3B3J', '3B3P', '3B3B', '3B31', '3B32', '3B33', '31JJ', '31JP', '31JB', '31J1', '31J2', '31J3', '31PJ', '31PP', '31PB', '31P1', '31P2', '31P3', '31BJ', '31BP', '31BB', '31B1', '31B2', '31B3', '311J', '311P', '311B', '3111', '3112', '3113', '312J', '312P', '312B', '3121', '3122', '3123', '313J', '313P', '313B', '3131', '3132', '3133', '32JJ', '32JP', '32JB', '32J1', '32J2', '32J3', '32PJ', '32PP', '32PB', '32P1', '32P2', '32P3', '32BJ', '32BP', '32BB', '32B1', '32B2', '32B3', '321J', '321P', '321B', '3211', '3212', '3213', '322J', '322P', '322B', '3221', '3222', '3223', '323J', '323P', '323B', '3231', '3232', '3233', '33JJ', '33JP', '33JB', '33J1', '33J2', '33J3', '33PJ', '33PP', '33PB', '33P1', '33P2', '33P3', '33BJ', '33BP', '33BB', '33B1', '33B2', '33B3', '331J', '331P', '331B', '3311', '3312', '3313', '332J', '332P', '332B', '3321', '3322', '3323', '333J', '333P', '333B', '3331', '3332', '3333']
# Returning ['JJJJ', 'JJJP', 'JJJB', 'JJJ1', 'JJJ2', 'JJJ3', 'JJPJ', 'JJPP', 'JJPB', 'JJP1', 'JJP2', 'JJP3', 'JJBJ', 'JJBP', 'JJBB', 'JJB1', 'JJB2', 'JJB3', 'JJ1J', 'JJ1P', 'JJ1B', 'JJ11', 'JJ12', 'JJ13', 'JJ2J', 'JJ2P', 'JJ2B', 'JJ21', 'JJ22', 'JJ23', 'JJ3J', 'JJ3P', 'JJ3B', 'JJ31', 'JJ32', 'JJ33', 'JPJJ', 'JPJP', 'JPJB', 'JPJ1', 'JPJ2', 'JPJ3', 'JPPJ', 'JPPP', 'JPPB', 'JPP1', 'JPP2', 'JPP3', 'JPBJ', 'JPBP', 'JPBB', 'JPB1', 'JPB2', 'JPB3', 'JP1J', 'JP1P', 'JP1B', 'JP11', 'JP12', 'JP13', 'JP2J', 'JP2P', 'JP2B', 'JP21', 'JP22', 'JP23', 'JP3J', 'JP3P', 'JP3B', 'JP31', 'JP32', 'JP33', 'JBJJ', 'JBJP', 'JBJB', 'JBJ1', 'JBJ2', 'JBJ3', 'JBPJ', 'JBPP', 'JBPB', 'JBP1', 'JBP2', 'JBP3', 'JBBJ', 'JBBP', 'JBBB', 'JBB1', 'JBB2', 'JBB3', 'JB1J', 'JB1P', 'JB1B', 'JB11', 'JB12', 'JB13', 'JB2J', 'JB2P', 'JB2B', 'JB21', 'JB22', 'JB23', 'JB3J', 'JB3P', 'JB3B', 'JB31', 'JB32', 'JB33', 'J1JJ', 'J1JP', 'J1JB', 'J1J1', 'J1J2', 'J1J3', 'J1PJ', 'J1PP', 'J1PB', 'J1P1', 'J1P2', 'J1P3', 'J1BJ', 'J1BP', 'J1BB', 'J1B1', 'J1B2', 'J1B3', 'J11J', 'J11P', 'J11B', 'J111', 'J112', 'J113', 'J12J', 'J12P', 'J12B', 'J121', 'J122', 'J123', 'J13J', 'J13P', 'J13B', 'J131', 'J132', 'J133', 'J2JJ', 'J2JP', 'J2JB', 'J2J1', 'J2J2', 'J2J3', 'J2PJ', 'J2PP', 'J2PB', 'J2P1', 'J2P2', 'J2P3', 'J2BJ', 'J2BP', 'J2BB', 'J2B1', 'J2B2', 'J2B3', 'J21J', 'J21P', 'J21B', 'J211', 'J212', 'J213', 'J22J', 'J22P', 'J22B', 'J221', 'J222', 'J223', 'J23J', 'J23P', 'J23B', 'J231', 'J232', 'J233', 'J3JJ', 'J3JP', 'J3JB', 'J3J1', 'J3J2', 'J3J3', 'J3PJ', 'J3PP', 'J3PB', 'J3P1', 'J3P2', 'J3P3', 'J3BJ', 'J3BP', 'J3BB', 'J3B1', 'J3B2', 'J3B3', 'J31J', 'J31P', 'J31B', 'J311', 'J312', 'J313', 'J32J', 'J32P', 'J32B', 'J321', 'J322', 'J323', 'J33J', 'J33P', 'J33B', 'J331', 'J332', 'J333', 'PJJJ', 'PJJP', 'PJJB', 'PJJ1', 'PJJ2', 'PJJ3', 'PJPJ', 'PJPP', 'PJPB', 'PJP1', 'PJP2', 'PJP3', 'PJBJ', 'PJBP', 'PJBB', 'PJB1', 'PJB2', 'PJB3', 'PJ1J', 'PJ1P', 'PJ1B', 'PJ11', 'PJ12', 'PJ13', 'PJ2J', 'PJ2P', 'PJ2B', 'PJ21', 'PJ22', 'PJ23', 'PJ3J', 'PJ3P', 'PJ3B', 'PJ31', 'PJ32', 'PJ33', 'PPJJ', 'PPJP', 'PPJB', 'PPJ1', 'PPJ2', 'PPJ3', 'PPPJ', 'PPPP', 'PPPB', 'PPP1', 'PPP2', 'PPP3', 'PPBJ', 'PPBP', 'PPBB', 'PPB1', 'PPB2', 'PPB3', 'PP1J', 'PP1P', 'PP1B', 'PP11', 'PP12', 'PP13', 'PP2J', 'PP2P', 'PP2B', 'PP21', 'PP22', 'PP23', 'PP3J', 'PP3P', 'PP3B', 'PP31', 'PP32', 'PP33', 'PBJJ', 'PBJP', 'PBJB', 'PBJ1', 'PBJ2', 'PBJ3', 'PBPJ', 'PBPP', 'PBPB', 'PBP1', 'PBP2', 'PBP3', 'PBBJ', 'PBBP', 'PBBB', 'PBB1', 'PBB2', 'PBB3', 'PB1J', 'PB1P', 'PB1B', 'PB11', 'PB12', 'PB13', 'PB2J', 'PB2P', 'PB2B', 'PB21', 'PB22', 'PB23', 'PB3J', 'PB3P', 'PB3B', 'PB31', 'PB32', 'PB33', 'P1JJ', 'P1JP', 'P1JB', 'P1J1', 'P1J2', 'P1J3', 'P1PJ', 'P1PP', 'P1PB', 'P1P1', 'P1P2', 'P1P3', 'P1BJ', 'P1BP', 'P1BB', 'P1B1', 'P1B2', 'P1B3', 'P11J', 'P11P', 'P11B', 'P111', 'P112', 'P113', 'P12J', 'P12P', 'P12B', 'P121', 'P122', 'P123', 'P13J', 'P13P', 'P13B', 'P131', 'P132', 'P133', 'P2JJ', 'P2JP', 'P2JB', 'P2J1', 'P2J2', 'P2J3', 'P2PJ', 'P2PP', 'P2PB', 'P2P1', 'P2P2', 'P2P3', 'P2BJ', 'P2BP', 'P2BB', 'P2B1', 'P2B2', 'P2B3', 'P21J', 'P21P', 'P21B', 'P211', 'P212', 'P213', 'P22J', 'P22P', 'P22B', 'P221', 'P222', 'P223', 'P23J', 'P23P', 'P23B', 'P231', 'P232', 'P233', 'P3JJ', 'P3JP', 'P3JB', 'P3J1', 'P3J2', 'P3J3', 'P3PJ', 'P3PP', 'P3PB', 'P3P1', 'P3P2', 'P3P3', 'P3BJ', 'P3BP', 'P3BB', 'P3B1', 'P3B2', 'P3B3', 'P31J', 'P31P', 'P31B', 'P311', 'P312', 'P313', 'P32J', 'P32P', 'P32B', 'P321', 'P322', 'P323', 'P33J', 'P33P', 'P33B', 'P331', 'P332', 'P333', 'BJJJ', 'BJJP', 'BJJB', 'BJJ1', 'BJJ2', 'BJJ3', 'BJPJ', 'BJPP', 'BJPB', 'BJP1', 'BJP2', 'BJP3', 'BJBJ', 'BJBP', 'BJBB', 'BJB1', 'BJB2', 'BJB3', 'BJ1J', 'BJ1P', 'BJ1B', 'BJ11', 'BJ12', 'BJ13', 'BJ2J', 'BJ2P', 'BJ2B', 'BJ21', 'BJ22', 'BJ23', 'BJ3J', 'BJ3P', 'BJ3B', 'BJ31', 'BJ32', 'BJ33', 'BPJJ', 'BPJP', 'BPJB', 'BPJ1', 'BPJ2', 'BPJ3', 'BPPJ', 'BPPP', 'BPPB', 'BPP1', 'BPP2', 'BPP3', 'BPBJ', 'BPBP', 'BPBB', 'BPB1', 'BPB2', 'BPB3', 'BP1J', 'BP1P', 'BP1B', 'BP11', 'BP12', 'BP13', 'BP2J', 'BP2P', 'BP2B', 'BP21', 'BP22', 'BP23', 'BP3J ...
# ['JJJJ', 'JJJP', 'JJJB', 'JJJ1', 'JJJ2', 'JJJ3', 'JJPJ', 'JJPP', 'JJPB', 'JJP1', 'JJP2', 'JJP3', 'JJBJ', 'JJBP', 'JJBB', 'JJB1', 'JJB2', 'JJB3', 'JJ1J', 'JJ1P', 'JJ1B', 'JJ11', 'JJ12', 'JJ13', 'JJ2J', 'JJ2P', 'JJ2B', 'JJ21', 'JJ22', 'JJ23', 'JJ3J', 'JJ3P', 'JJ3B', 'JJ31', 'JJ32', 'JJ33', 'JPJJ', 'JPJP', 'JPJB', 'JPJ1', 'JPJ2', 'JPJ3', 'JPPJ', 'JPPP', 'JPPB', 'JPP1', 'JPP2', 'JPP3', 'JPBJ', 'JPBP', 'JPBB', 'JPB1', 'JPB2', 'JPB3', 'JP1J', 'JP1P', 'JP1B', 'JP11', 'JP12', 'JP13', 'JP2J', 'JP2P', 'JP2B', 'JP21', 'JP22', 'JP23', 'JP3J', 'JP3P', 'JP3B', 'JP31', 'JP32', 'JP33', 'JBJJ', 'JBJP', 'JBJB', 'JBJ1', 'JBJ2', 'JBJ3', 'JBPJ', 'JBPP', 'JBPB', 'JBP1', 'JBP2', 'JBP3', 'JBBJ', 'JBBP', 'JBBB', 'JBB1', 'JBB2', 'JBB3', 'JB1J', 'JB1P', 'JB1B', 'JB11', 'JB12', 'JB13', 'JB2J', 'JB2P', 'JB2B', 'JB21', 'JB22', 'JB23', 'JB3J', 'JB3P', 'JB3B', 'JB31', 'JB32', 'JB33', 'J1JJ', 'J1JP', 'J1JB', 'J1J1', 'J1J2', 'J1J3', 'J1PJ', 'J1PP', 'J1PB', 'J1P1', 'J1P2', 'J1P3', 'J1BJ', 'J1BP', 'J1BB', 'J1B1', 'J1B2', 'J1B3', 'J11J', 'J11P', 'J11B', 'J111', 'J112', 'J113', 'J12J', 'J12P', 'J12B', 'J121', 'J122', 'J123', 'J13J', 'J13P', 'J13B', 'J131', 'J132', 'J133', 'J2JJ', 'J2JP', 'J2JB', 'J2J1', 'J2J2', 'J2J3', 'J2PJ', 'J2PP', 'J2PB', 'J2P1', 'J2P2', 'J2P3', 'J2BJ', 'J2BP', 'J2BB', 'J2B1', 'J2B2', 'J2B3', 'J21J', 'J21P', 'J21B', 'J211', 'J212', 'J213', 'J22J', 'J22P', 'J22B', 'J221', 'J222', 'J223', 'J23J', 'J23P', 'J23B', 'J231', 'J232', 'J233', 'J3JJ', 'J3JP', 'J3JB', 'J3J1', 'J3J2', 'J3J3', 'J3PJ', 'J3PP', 'J3PB', 'J3P1', 'J3P2', 'J3P3', 'J3BJ', 'J3BP', 'J3BB', 'J3B1', 'J3B2', 'J3B3', 'J31J', 'J31P', 'J31B', 'J311', 'J312', 'J313', 'J32J', 'J32P', 'J32B', 'J321', 'J322', 'J323', 'J33J', 'J33P', 'J33B', 'J331', 'J332', 'J333', 'PJJJ', 'PJJP', 'PJJB', 'PJJ1', 'PJJ2', 'PJJ3', 'PJPJ', 'PJPP', 'PJPB', 'PJP1', 'PJP2', 'PJP3', 'PJBJ', 'PJBP', 'PJBB', 'PJB1', 'PJB2', 'PJB3', 'PJ1J', 'PJ1P', 'PJ1B', 'PJ11', 'PJ12', 'PJ13', 'PJ2J', 'PJ2P', 'PJ2B', 'PJ21', 'PJ22', 'PJ23', 'PJ3J', 'PJ3P', 'PJ3B', 'PJ31', 'PJ32', 'PJ33', 'PPJJ', 'PPJP', 'PPJB', 'PPJ1', 'PPJ2', 'PPJ3', 'PPPJ', 'PPPP', 'PPPB', 'PPP1', 'PPP2', 'PPP3', 'PPBJ', 'PPBP', 'PPBB', 'PPB1', 'PPB2', 'PPB3', 'PP1J', 'PP1P', 'PP1B', 'PP11', 'PP12', 'PP13', 'PP2J', 'PP2P', 'PP2B', 'PP21', 'PP22', 'PP23', 'PP3J', 'PP3P', 'PP3B', 'PP31', 'PP32', 'PP33', 'PBJJ', 'PBJP', 'PBJB', 'PBJ1', 'PBJ2', 'PBJ3', 'PBPJ', 'PBPP', 'PBPB', 'PBP1', 'PBP2', 'PBP3', 'PBBJ', 'PBBP', 'PBBB', 'PBB1', 'PBB2', 'PBB3', 'PB1J', 'PB1P', 'PB1B', 'PB11', 'PB12', 'PB13', 'PB2J', 'PB2P', 'PB2B', 'PB21', 'PB22', 'PB23', 'PB3J', 'PB3P', 'PB3B', 'PB31', 'PB32', 'PB33', 'P1JJ', 'P1JP', 'P1JB', 'P1J1', 'P1J2', 'P1J3', 'P1PJ', 'P1PP', 'P1PB', 'P1P1', 'P1P2', 'P1P3', 'P1BJ', 'P1BP', 'P1BB', 'P1B1', 'P1B2', 'P1B3', 'P11J', 'P11P', 'P11B', 'P111', 'P112', 'P113', 'P12J', 'P12P', 'P12B', 'P121', 'P122', 'P123', 'P13J', 'P13P', 'P13B', 'P131', 'P132', 'P133', 'P2JJ', 'P2JP', 'P2JB', 'P2J1', 'P2J2', 'P2J3', 'P2PJ', 'P2PP', 'P2PB', 'P2P1', 'P2P2', 'P2P3', 'P2BJ', 'P2BP', 'P2BB', 'P2B1', 'P2B2', 'P2B3', 'P21J', 'P21P', 'P21B', 'P211', 'P212', 'P213', 'P22J', 'P22P', 'P22B', 'P221', 'P222', 'P223', 'P23J', 'P23P', 'P23B', 'P231', 'P232', 'P233', 'P3JJ', 'P3JP', 'P3JB', 'P3J1', 'P3J2', 'P3J3', 'P3PJ', 'P3PP', 'P3PB', 'P3P1', 'P3P2', 'P3P3', 'P3BJ', 'P3BP', 'P3BB', 'P3B1', 'P3B2', 'P3B3', 'P31J', 'P31P', 'P31B', 'P311', 'P312', 'P313', 'P32J', 'P32P', 'P32B', 'P321', 'P322', 'P323', 'P33J', 'P33P', 'P33B', 'P331', 'P332', 'P333', 'BJJJ', 'BJJP', 'BJJB', 'BJJ1', 'BJJ2', 'BJJ3', 'BJPJ', 'BJPP', 'BJPB', 'BJP1', 'BJP2', 'BJP3', 'BJBJ', 'BJBP', 'BJBB', 'BJB1', 'BJB2', 'BJB3', 'BJ1J', 'BJ1P', 'BJ1B', 'BJ11', 'BJ12', 'BJ13', 'BJ2J', 'BJ2P', 'BJ2B', 'BJ21', 'BJ22', 'BJ23', 'BJ3J', 'BJ3P', 'BJ3B', 'BJ31', 'BJ32', 'BJ33', 'BPJJ', 'BPJP', 'BPJB', 'BPJ1', 'BPJ2', 'BPJ3', 'BPPJ', 'BPPP', 'BPPB', 'BPP1', 'BPP2', 'BPP3', 'BPBJ', 'BPBP', 'BPBB', 'BPB1', 'BPB2', 'BPB3', 'BP1J', 'BP1P', 'BP1B', 'BP11', 'BP12', 'BP13', 'BP2J', 'BP2P', 'BP2B', 'BP21', 'BP22', 'BP23', 'BP3J', 'BP3P', ...
